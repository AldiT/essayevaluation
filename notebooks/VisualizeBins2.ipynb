# %%
from bs4 import BeautifulSoup as BS
import numpy as np
import pandas as pd

# %%
features_lv = ['LV_W', 'LV_WT', 'LV_WT1', 'LV_TTR', 'LV_CTTR', 'LV_RTTR', 'LV_HDD', 'LV_DUGA', 'LV_MAAS', 'LV_SUMM',
                         'LV_YULEK','LV_MTLD','LV_MSTTR','LV_MATTR']

#14 features
features_ls = ["LS_FPC_NG", "LS_FPC_NA", "LS_FPC_TC", "LS_FPC_BS", "LS_FPC_CA", "LS_FPC_CT", "LS_FPC_CGA1",
            "LS_FPC_CGA2", "LS_FPC_CGA3", "LS_FOMN_NG", "LS_FOMN_NA", "LS_FOMN_TC", "LS_FOMN_BS", "LS_FOMN_CA"]
#3 features
features_la = ["LA_ER", "LA_COL_ERR_R"]
#6 features
features_ca = ["CA_BIN1_R", "CA_BIN2_R", "CA_BIN3_R"]
#2 features
features_ld = ["LD_LXUR", "LD_GRUR"]

feature_names = features_lv + features_ls + features_la + features_ca + features_ld
feature_names = np.array(feature_names)
binning_indicies = [6, 18, 19, 20, 21, 22, 28, 29, 30, 31, 32, 33]

# %%
#pipeline

# %%
level = "a1"
path_to_bins = "bins/bin_values_level_"+level+".xml"
file = open(path_to_bins, "r")
bs = BS(file, "lxml")

binning_criterias = []

features = bs.find_all("feature")

feature_indicies = []
means = []
stdds = []

for index, feature in enumerate(features):
    feature_indicies.append(int(feature.find("feature_index").text))
    means.append(float(feature.find("mean").text))
    stdds.append(float(feature.find("std").text))

feature_indicies = np.array(feature_indicies).round(4)
means = np.array(means).round(4)
stdds = np.array(stdds).round(4)

data = np.vstack((feature_indicies, feature_names[binning_indicies], means, stdds, (means-stdds).round(4), (means+stdds).round(4)))
#print(data)
columns = ["Feature Index", "Feature code", "Mean", "Standard deviation", "mean-std", "mean+std"]

df = pd.DataFrame(data.T, columns=columns)


#read essays
essay_file = "dataset_binned/level_" + level + ".xml"
essays = []
grades = []
index = 0
with open(essay_file, "r") as f:
    bs = BS(f, "lxml")
    writings = bs.find_all("writing")
    for writing in writings:
        #if np.random.normal() < 0.1:
        #    continue
        essays.append(writing.find("text").text)
        grades.append(int(writing.find("grade").text))
        index += 1
        if index == 1000:
            break

bins = []

grades = np.array(grades)
feature_matrix = np.load("all_features_1000/feature_matrix_"+level+"_fm.npy")
grades_test = np.load("all_features_1000/feature_matrix_"+level+"_grades.npy")
assert (grades_test == grades).all()

for index, mean, std in zip(feature_indicies, means, stdds):
    bin1 = len(feature_matrix.T[index, feature_matrix.T[index] <= (mean-std)])
    bin2 = len(feature_matrix.T[index, ((feature_matrix.T[index] <= mean) &  (feature_matrix.T[index] > (mean - std)))])
    bin3 = len(feature_matrix.T[index, ((feature_matrix.T[index] < (mean+std)) &  (feature_matrix.T[index] > mean)) ])
    bin4 = len(feature_matrix.T[index, feature_matrix.T[index] >= (mean+std)]  )
    
    print("Feature code: ", feature_names[index])
    print("Bin1: {}%".format(bin1/10))
    print("Bin2: {}%".format(bin2/10))
    print("Bin3: {}%".format(bin3/10))
    print("Bin4: {}%".format(bin4/10))
    print()
    
    negative_feedback_index = np.argmax((feature_matrix.T[index] <= mean-std)) if ((feature_matrix.T[index] <= mean-std) != False).any() else -1
    neutral_feedback_index = np.argmax((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std))) if ((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std)) != False).any() else -1
    positive_feedback_index = np.argmax((feature_matrix.T[index] >= mean+std)) if ((feature_matrix.T[index] >= mean+std) != False).any() else -1
    
    if feature_names[index] == "LA_ER" or feature_names[index] == "LA_COL_ERR_R" or feature_names[index] == "CA_BIN1_R":
        temp = negative_feedback_index
        negative_feedback_index = positive_feedback_index
        positive_feedback_index = temp
        
    
    print("3 sample essays")
    print("Mean: {}, std: {}, Mean-std: {}, mean+std: {}".format(mean, std, mean-std, mean+std))
    print("---------------------------------------------------------------------------")
    print("Feedback: Positive")
    print("Essay: {}".format(essays[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Neutral")
    print("Essay: {}".format(essays[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Negative")
    print("Essay: {}".format(essays[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n\n".format(feature_matrix.T[index, negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("===========================================================================")
# Out:
# Feature code:  LV_HDD
# Bin1: 0.0%
# Bin2: 91.4%
# Bin3: 0.0%
# Bin4: 8.6%
#
# 3 sample essays
# Mean: 0.0608, std: 0.2002, Mean-std: -0.1394, mean+std: 0.261
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       I know a hotel in the city center next to the train station. it is very well placed for 5 min you a tram station and you're up to 10 min for shopping. It is located north of Montpellier in a beautiful area
#
# Grade: 80
# Feature value: 0.7380952380952386
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.0
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  LS_FPC_CA
# Bin1: 0.0%
# Bin2: 79.2%
# Bin3: 0.0%
# Bin4: 20.8%
#
# 3 sample essays
# Mean: 0.005, std: 0.0108, Mean-std: -0.0058000000000000005, mean+std: 0.0158
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Hi!This is the Chinese menu,because I'm from China,.If we have a part,we will eat somethings,for example:rice,milk,beef,fish,meat,eggs,vegetable,chicken,wine,tea and so on
#
# Grade: 96
# Feature value: 0.020833333333333332
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.0
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  LS_FPC_CT
# Bin1: 0.0%
# Bin2: 51.8%
# Bin3: 37.9%
# Bin4: 10.3%
#
# 3 sample essays
# Mean: 0.0413, std: 0.0434, Mean-std: -0.0020999999999999977, mean+std: 0.0847
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Hi!This is the Chinese menu,because I'm from China,.If we have a part,we will eat somethings,for example:rice,milk,beef,fish,meat,eggs,vegetable,chicken,wine,tea and so on
#
# Grade: 96
# Feature value: 0.1875
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.020833333333333332
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  LS_FPC_CGA1
# Bin1: 15.4%
# Bin2: 35.9%
# Bin3: 36.1%
# Bin4: 12.6%
#
# 3 sample essays
# Mean: 0.2974, std: 0.0785, Mean-std: 0.21889999999999998, mean+std: 0.3759
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       I know a hotel in the city center next to the train station. it is very well placed for 5 min you a tram station and you're up to 10 min for shopping. It is located north of Montpellier in a beautiful area
#
# Grade: 80
# Feature value: 0.4375
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.2916666666666667
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Date: Monday 11th Time:9;30am Message for: Mr.Jones Form:Maragret Kendall Telephone number:###### #### Message: Lunch with Margaret Kendall, Tuesday 12th,at La Maison restaurant Taken by :Keira
#
# Grade: 100
# Feature value: 0.14893617021276595
#
#
# ===========================================================================
# Feature code:  LS_FPC_CGA2
# Bin1: 0.0%
# Bin2: 51.4%
# Bin3: 37.1%
# Bin4: 11.5%
#
# 3 sample essays
# Mean: 0.013, std: 0.0155, Mean-std: -0.0025000000000000005, mean+std: 0.028499999999999998
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Hi, buddy! Well... my favorite restaurant is the &quot;Guaiamum Gigante&quot;. They serve a delicious Brasilian food there. The prices are good (cheap) and the waiters are so friendly. The fishes and soups are marvelous. I recommend!
#
# Grade: 90
# Feature value: 0.041666666666666664
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.020833333333333332
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  LS_FPC_CGA3
# Bin1: 0.0%
# Bin2: 87.1%
# Bin3: 0.0%
# Bin4: 12.9%
#
# 3 sample essays
# Mean: 0.0027, std: 0.0072, Mean-std: -0.0045, mean+std: 0.009899999999999999
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Hello Anna !!!My name's Larissa. Nice to meet you.What's phone number? I'm (##) ####-####How old are you? I'm 26 years old. Bye bye. Kisses.
#
# Grade: 88
# Feature value: 0.020833333333333332
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.0
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  LA_ER
# Bin1: 0.0%
# Bin2: 72.8%
# Bin3: 15.8%
# Bin4: 11.4%
#
# 3 sample essays
# Mean: 0.022, std: 0.0266, Mean-std: -0.0046, mean+std: 0.0486
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.041666666666666664
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Name: JonathanAge: 22Birthday: 26 NovemberLike doing: cooking, reading, surfing the internet, playing soccer, writing, watching TV and chatting with friends.Live in: Nevada, USA.FavoriteSeason: autumnAnimal: LionTime: AfternoonDay: SaturdayNumber: 26
#
# Grade: 100
# Feature value: 0.125
#
#
# ===========================================================================
# Feature code:  LA_COL_ERR_R
# Bin1: 16.4%
# Bin2: 29.7%
# Bin3: 38.0%
# Bin4: 15.9%
#
# 3 sample essays
# Mean: 0.4991, std: 0.2011, Mean-std: 0.298, mean+std: 0.7001999999999999
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       In my country, the price of everything is going up. Housing is very expensive, and the price of gasoline is increasing quickly. Transportation and food are expensive too and they are going up. The cost of living is very difficult.
#
# Grade: 100
# Feature value: 0.07142857142857142
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.5
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Date: Monday 11th Time:9;30am Message for: Mr.Jones Form:Maragret Kendall Telephone number:###### #### Message: Lunch with Margaret Kendall, Tuesday 12th,at La Maison restaurant Taken by :Keira
#
# Grade: 100
# Feature value: 1.0
#
#
# ===========================================================================
# Feature code:  CA_BIN1_R
# Bin1: 0.0%
# Bin2: 54.0%
# Bin3: 35.1%
# Bin4: 10.9%
#
# 3 sample essays
# Mean: 0.161, std: 0.1778, Mean-std: -0.01680000000000001, mean+std: 0.3388
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.16666666666666666
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Name: JonathanAge: 22Birthday: 26 NovemberLike doing: cooking, reading, surfing the internet, playing soccer, writing, watching TV and chatting with friends.Live in: Nevada, USA.FavoriteSeason: autumnAnimal: LionTime: AfternoonDay: SaturdayNumber: 26
#
# Grade: 100
# Feature value: 1.0
#
#
# ===========================================================================
# Feature code:  CA_BIN2_R
# Bin1: 0.0%
# Bin2: 60.1%
# Bin3: 23.2%
# Bin4: 16.7%
#
# 3 sample essays
# Mean: 0.0983, std: 0.143, Mean-std: -0.04469999999999999, mean+std: 0.2413
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.3333333333333333
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Date: Monday 11th Time:9;30am Message for: Mr.Jones Form:Maragret Kendall Telephone number:###### #### Message: Lunch with Margaret Kendall, Tuesday 12th,at La Maison restaurant Taken by :Keira
#
# Grade: 100
# Feature value: 0.0
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  CA_BIN3_R
# Bin1: 9.8%
# Bin2: 36.2%
# Bin3: 31.2%
# Bin4: 22.8%
#
# 3 sample essays
# Mean: 0.7238, std: 0.2288, Mean-std: 0.495, mean+std: 0.9526
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Tom's Saturday On Saturday he's really busy. At 11:30 he goes swimming and at 12:30 he eats lunch. Then, at 16:00, he reads his emails and at 18:00 he eats dinner. After that he watches TV at 22:00.
#
# Grade: 90
# Feature value: 1.0
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.5
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Date: Monday 11th Time:9;30am Message for: Mr.Jones Form:Maragret Kendall Telephone number:###### #### Message: Lunch with Margaret Kendall, Tuesday 12th,at La Maison restaurant Taken by :Keira
#
# Grade: 100
# Feature value: 0.0
#
#
# ===========================================================================
# Feature code:  LD_LXUR
# Bin1: 15.3%
# Bin2: 36.9%
# Bin3: 31.5%
# Bin4: 16.3%
#
# 3 sample essays
# Mean: 0.4389, std: 0.089, Mean-std: 0.3499, mean+std: 0.5279
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       In the office there are computer, mouse. There are a lot of pen and pencil. There are a few windows. There are some desk and somechair. There are a few meeting rooms , restroons. There''s a Kitchen.
#
# Grade: 95
# Feature value: 0.5416666666666666
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hi!This is the Chinese menu,because I'm from China,.If we have a part,we will eat somethings,for example:rice,milk,beef,fish,meat,eggs,vegetable,chicken,wine,tea and so on
#
# Grade: 96
# Feature value: 0.4583333333333333
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Date: Monday 11th Time:9;30am Message for: Mr.Jones Form:Maragret Kendall Telephone number:###### #### Message: Lunch with Margaret Kendall, Tuesday 12th,at La Maison restaurant Taken by :Keira
#
# Grade: 100
# Feature value: 0.2916666666666667
#
#
# ===========================================================================

# %% [markdown]
# <h1>Level A2 bin percentages</h1>

# %%
level = "a2"
path_to_bins = "bins/bin_values_level_"+level+".xml"
file = open(path_to_bins, "r")
bs = BS(file, "lxml")

binning_criterias = []

features = bs.find_all("feature")

feature_indicies = []
means = []
stdds = []

for index, feature in enumerate(features):
    feature_indicies.append(int(feature.find("feature_index").text))
    means.append(float(feature.find("mean").text))
    stdds.append(float(feature.find("std").text))

feature_indicies = np.array(feature_indicies).round(4)
means = np.array(means).round(4)
stdds = np.array(stdds).round(4)

data = np.vstack((feature_indicies, feature_names[binning_indicies], means, stdds, (means-stdds).round(4), (means+stdds).round(4)))
#print(data)
columns = ["Feature Index", "Feature code", "Mean", "Standard deviation", "mean-std", "mean+std"]

df = pd.DataFrame(data.T, columns=columns)


#read essays
essay_file = "dataset_binned/level_" + level + ".xml"
essays = []
grades = []
index = 0
with open(essay_file, "r") as f:
    bs = BS(f, "lxml")
    writings = bs.find_all("writing")
    for writing in writings:
        #if np.random.normal() < 0.1:
        #    continue
        essays.append(writing.find("text").text)
        grades.append(int(writing.find("grade").text))
        index += 1
        if index == 1000:
            break

bins = []

grades = np.array(grades)
feature_matrix = np.load("all_features_1000/feature_matrix_"+level+"_fm.npy")
grades_test = np.load("all_features_1000/feature_matrix_"+level+"_grades.npy")
assert (grades_test == grades).all()

for index, mean, std in zip(feature_indicies, means, stdds):
    bin1 = len(feature_matrix.T[index, feature_matrix.T[index] <= (mean-std)])
    bin2 = len(feature_matrix.T[index, ((feature_matrix.T[index] <= mean) &  (feature_matrix.T[index] > (mean - std)))])
    bin3 = len(feature_matrix.T[index, ((feature_matrix.T[index] < (mean+std)) &  (feature_matrix.T[index] > mean)) ])
    bin4 = len(feature_matrix.T[index, feature_matrix.T[index] >= (mean+std)]  )
    
    print("Feature code: ", feature_names[index])
    print("Bin1: {}%".format(bin1/10))
    print("Bin2: {}%".format(bin2/10))
    print("Bin3: {}%".format(bin3/10))
    print("Bin4: {}%".format(bin4/10))
    print()
    
    negative_feedback_index = np.argmax((feature_matrix.T[index] <= mean-std)) if ((feature_matrix.T[index] <= mean-std) != False).any() else -1
    neutral_feedback_index = np.argmax((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std))) if ((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std)) != False).any() else -1
    positive_feedback_index = np.argmax((feature_matrix.T[index] >= mean+std)) if ((feature_matrix.T[index] >= mean+std) != False).any() else -1
    
    if feature_names[index] == "LA_ER" or feature_names[index] == "LA_COL_ERR_R" or feature_names[index] == "CA_BIN1_R":
        temp = negative_feedback_index
        negative_feedback_index = positive_feedback_index
        positive_feedback_index = temp
    
    print("3 sample essays")
    print("Mean: {}, std: {}, Mean-std: {}, mean+std: {}".format(mean, std, mean-std, mean+std))
    print("---------------------------------------------------------------------------")
    print("Feedback: Positive")
    print("Essay: {}".format(essays[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Neutral")
    print("Essay: {}".format(essays[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Negative")
    print("Essay: {}".format(essays[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n\n".format(feature_matrix.T[index, negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("===========================================================================")
# Out:
# Feature code:  LV_HDD
# Bin1: 16.8%
# Bin2: 29.5%
# Bin3: 38.3%
# Bin4: 15.4%
#
# 3 sample essays
# Mean: 0.7594, std: 0.0729, Mean-std: 0.6865, mean+std: 0.8322999999999999
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       To: xxx@gamil.com From: xxx@gamil.com Subject: networking event Hi, Amy. I just returned from a successful networking event with Tom. There were hundred of fashion designers at La Tom sharing contacts and ideas for new look. I think that Roman Scalio was excited about my sping desighs. Maybe he'll call me! I guess that he liked the Balinese fabrics. i'll tell you more on Monday! Winnie
#
# Grade: 95
# Feature value: 0.8843945171454981
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       April 24, 2013 To whom it may concem: I highly recommend Jon Carll to you company. I worked with Mr. Carll for 8 years at Bell Shop. Mr. Carll was sales assistant at Bell Shop. He was really helpful. He had very good ideas for the company. He was very hardworking. Please feel free to contact me about Jon at xxx@shop.com Sincerely, Bruno Duarte Director sales of Bell Shop
#
# Grade: 95
# Feature value: 0.7722949424002966
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       I get up at 7am.I make the bed at 7:30am I feed the dog at 8am every day.I don't play the guitar and i don't do yoga.I surf the internet every day.I wash the dishes after dinner every day.I walk the dog in the afternoon.I watch movie every day at 6pm.I feed the dog again at 5 pm every day.
#
# Grade: 100
# Feature value: 0.5542141007128988
#
#
# ===========================================================================
# Feature code:  LS_FPC_CA
# Bin1: 0.0%
# Bin2: 54.6%
# Bin3: 34.1%
# Bin4: 11.3%
#
# 3 sample essays
# Mean: 0.0108, std: 0.0156, Mean-std: -0.004799999999999999, mean+std: 0.0264
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Hereafter is the new dress code begenning tomorrow : In general, clothes too short or too baggy or too tight are not permitted. Mens can wear suits with dark ot white shirt. They can wear also jeans. Women's can wear dress or skirt with cotton top or blouse. Light jewellery is authorised. We prefer natural fabrics for all clothes if it's possible. Thanks for your attention. Office manager
#
# Grade: 88
# Feature value: 0.05
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       To: xxx@gamil.com From: xxx@gamil.com Subject: networking event Hi, Amy. I just returned from a successful networking event with Tom. There were hundred of fashion designers at La Tom sharing contacts and ideas for new look. I think that Roman Scalio was excited about my sping desighs. Maybe he'll call me! I guess that he liked the Balinese fabrics. i'll tell you more on Monday! Winnie
#
# Grade: 95
# Feature value: 0.025
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  LS_FPC_CT
# Bin1: 9.1%
# Bin2: 41.9%
# Bin3: 30.9%
# Bin4: 18.1%
#
# 3 sample essays
# Mean: 0.0351, std: 0.0256, Mean-std: 0.009499999999999998, mean+std: 0.060700000000000004
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       To: xxx@gamil.com From: xxx@gamil.com Subject: networking event Hi, Amy. I just returned from a successful networking event with Tom. There were hundred of fashion designers at La Tom sharing contacts and ideas for new look. I think that Roman Scalio was excited about my sping desighs. Maybe he'll call me! I guess that he liked the Balinese fabrics. i'll tell you more on Monday! Winnie
#
# Grade: 95
# Feature value: 0.0
#
#
# ===========================================================================
# Feature code:  CA_BIN3_R
# Bin1: 16.2%
# Bin2: 30.9%
# Bin3: 36.9%
# Bin4: 16.0%
#
# 3 sample essays
# Mean: 0.6899, std: 0.1701, Mean-std: 0.5197999999999999, mean+std: 0.86
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       My name is Adriano Almeida. I was born in 1979. When I was children I lived in Brazil but when I was 16 I moved for Japan. I lived in Japan for 4 years. I studied guitar from 2000 to 2002 but today I play the guitar sometimes. I graduated in 2009. Now I'm a businessman. I married my wife Rosana in 2010. I'm very happy now.
#
# Grade: 96
# Feature value: 0.9
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       To: xxx@gamil.com From: xxx@gamil.com Subject: networking event Hi, Amy. I just returned from a successful networking event with Tom. There were hundred of fashion designers at La Tom sharing contacts and ideas for new look. I think that Roman Scalio was excited about my sping desighs. Maybe he'll call me! I guess that he liked the Balinese fabrics. i'll tell you more on Monday! Winnie
#
# Grade: 95
# Feature value: 0.6
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Sean plays basketball every afternoon. He plays computer games at 6 pm every day. And he wathes movies on Saturdays at 5 pm. Granny does laundry on Tuesday afternoon. She does gardening in the morning. Granny sets the table at 6 pm. I feed the dog at 8 am every day. I walk the dog inn the afternoon. And I feed the dog again at 5 pm every day.
#
# Grade: 94
# Feature value: 0.5
#
#
# ===========================================================================
# Feature code:  LD_LXUR
# Bin1: 13.4%
# Bin2: 33.4%
# Bin3: 40.2%
# Bin4: 13.0%
#
# 3 sample essays
# Mean: 0.4489, std: 0.0652, Mean-std: 0.38370000000000004, mean+std: 0.5141
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Hi, I'm Monise, I'm adult and I have happy family. My dad is tall and thin. He has short, brown hair, blue eyes and big month. My mother is small and fat. She has short, brown hais, brown eyes and big month too. I look like my father. I'm tall and fat. I have long, brown hais and blue eyes.
#
# Grade: 93
# Feature value: 0.525
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       I get up at 7am.I make the bed at 7:30am I feed the dog at 8am every day.I don't play the guitar and i don't do yoga.I surf the internet every day.I wash the dishes after dinner every day.I walk the dog in the afternoon.I watch movie every day at 6pm.I feed the dog again at 5 pm every day.
#
# Grade: 100
# Feature value: 0.4375
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       To: xxx@gamil.com From: xxx@gamil.com Subject: networking event Hi, Amy. I just returned from a successful networking event with Tom. There were hundred of fashion designers at La Tom sharing contacts and ideas for new look. I think that Roman Scalio was excited about my sping desighs. Maybe he'll call me! I guess that he liked the Balinese fabrics. i'll tell you more on Monday! Winnie
#
# Grade: 95
# Feature value: 0.375
#
#
# ===========================================================================

# %% [markdown]
# <h1>Level B1 bin percentages</h1>

# %%
level = "b1"
path_to_bins = "bins/bin_values_level_"+level+".xml"
file = open(path_to_bins, "r")
bs = BS(file, "lxml")

binning_criterias = []

features = bs.find_all("feature")

feature_indicies = []
means = []
stdds = []

for index, feature in enumerate(features):
    feature_indicies.append(int(feature.find("feature_index").text))
    means.append(float(feature.find("mean").text))
    stdds.append(float(feature.find("std").text))

feature_indicies = np.array(feature_indicies).round(4)
means = np.array(means).round(4)
stdds = np.array(stdds).round(4)

data = np.vstack((feature_indicies, feature_names[binning_indicies], means, stdds, (means-stdds).round(4), (means+stdds).round(4)))
#print(data)
columns = ["Feature Index", "Feature code", "Mean", "Standard deviation", "mean-std", "mean+std"]

df = pd.DataFrame(data.T, columns=columns)


#read essays
essay_file = "dataset_binned/level_" + level + ".xml"
essays = []
grades = []
index = 0
with open(essay_file, "r") as f:
    bs = BS(f, "lxml")
    writings = bs.find_all("writing")
    for writing in writings:
        #if np.random.normal() < 0.1:
        #    continue
        essays.append(writing.find("text").text)
        grades.append(int(writing.find("grade").text))
        index += 1
        if index == 1000:
            break

bins = []

grades = np.array(grades)
feature_matrix = np.load("all_features_1000/feature_matrix_"+level+"_fm.npy")
grades_test = np.load("all_features_1000/feature_matrix_"+level+"_grades.npy")
assert (grades_test == grades).all()

for index, mean, std in zip(feature_indicies, means, stdds):
    bin1 = len(feature_matrix.T[index, feature_matrix.T[index] <= (mean-std)])
    bin2 = len(feature_matrix.T[index, ((feature_matrix.T[index] <= mean) &  (feature_matrix.T[index] > (mean - std)))])
    bin3 = len(feature_matrix.T[index, ((feature_matrix.T[index] < (mean+std)) &  (feature_matrix.T[index] > mean)) ])
    bin4 = len(feature_matrix.T[index, feature_matrix.T[index] >= (mean+std)]  )
    
    print("Feature code: ", feature_names[index])
    print("Bin1: {}%".format(bin1/10))
    print("Bin2: {}%".format(bin2/10))
    print("Bin3: {}%".format(bin3/10))
    print("Bin4: {}%".format(bin4/10))
    print()
    
    negative_feedback_index = np.argmax((feature_matrix.T[index] <= mean-std)) if ((feature_matrix.T[index] <= mean-std) != False).any() else -1
    neutral_feedback_index = np.argmax((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std))) if ((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std)) != False).any() else -1
    positive_feedback_index = np.argmax((feature_matrix.T[index] >= mean+std)) if ((feature_matrix.T[index] >= mean+std) != False).any() else -1
    
    if feature_names[index] == "LA_ER" or feature_names[index] == "LA_COL_ERR_R" or feature_names[index] == "CA_BIN1_R":
        temp = negative_feedback_index
        negative_feedback_index = positive_feedback_index
        positive_feedback_index = temp
    
    print("3 sample essays")
    print("Mean: {}, std: {}, Mean-std: {}, mean+std: {}".format(mean, std, mean-std, mean+std))
    print("---------------------------------------------------------------------------")
    print("Feedback: Positive")
    print("Essay: {}".format(essays[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Neutral")
    print("Essay: {}".format(essays[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Negative")
    print("Essay: {}".format(essays[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n\n".format(feature_matrix.T[index, negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("===========================================================================")
# Out:
# Feature code:  LV_HDD
# Bin1: 14.3%
# Bin2: 34.7%
# Bin3: 37.2%
# Bin4: 13.8%
#
# 3 sample essays
# Mean: 0.8024, std: 0.0428, Mean-std: 0.7596, mean+std: 0.8452
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       I think education have some trouble in China.There are a lot of tests and plenty of homework. I 'm totally against that.  Seldom older people to go back to school. There are ranking in China. People are like comparing each other. Private school is popular in daily China, it's so expansive but seem every parents want the childrens join in it. Every student have to study hard for famous clloeges: such as QingHuang University and BeiJing University.it's said &quot;Thousands of soldiers and horses go through bridge&quot;.Of course .Chinese students are very bright and clever.
#
# Grade: 90
# Feature value: 0.8539977875338487
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Dear Mom i have been away for a long time, and i would like to give some news, i have talked with you aboult others big companies that are hiring news employes, i have sent my CV and received some feedbacks, i believe that i'll be contacted. i'm so happy, do you remember  Thiago that was my classmate, so he was unemployed and needing money. i felt sad with that situation, i'd like to help him, but i could'nt beside that he is drug addict.. i'll let you know what happens  Take care
#
# Grade: 80
# Feature value: 0.8064259623007953
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       First, I have to finish my phd in architecture. I want to publicate some papers in some scientific journals. Next, I want to get some international work experience, maybe in a anglo-saxon country, so I have to learn english. I could do an internship in an architecture office. I also wants to perfect my language skills in french. I want to take part in an international architecture competition to improve my skills in design. After doing all this, I hope to have an important network of contacts that allows me to create my own architecture office.
#
# Grade: 88
# Feature value: 0.7122105937795132
#
#
# ===========================================================================
# Feature code:  LS_FPC_CA
# Bin1: 23.3%
# Bin2: 35.8%
# Bin3: 23.0%
# Bin4: 17.9%
#
# 3 sample essays
# Mean: 0.0222, std: 0.0216, Mean-std: 0.0005999999999999998, mean+std: 0.043800000000000006
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       First, I have to finish my phd in architecture. I want to publicate some papers in some scientific journals. Next, I want to get some international work experience, maybe in a anglo-saxon country, so I have to learn english. I could do an internship in an architecture office. I also wants to perfect my language skills in french. I want to take part in an international architecture competition to improve my skills in design. After doing all this, I hope to have an important network of contacts that allows me to create my own architecture office.
#
# Grade: 88
# Feature value: 0
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Hi Anna, Hope you are well. Do you remember how we studied our accountantcy classes? Now I am an accountant but I fill that it is boring. I've decided to change my life totally and become an artist. I continue to work as an accountant but I've got evening classes of arts. I always like to do something by my hands and recently I've discovered the whole world of drawing and painting. It's really amazing to make a picture of something like a tree or an animal by only one pencil. It's really great. Yours,
#
# Grade: 95
# Feature value: 0.03571428571428571
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       First, I have to finish my phd in architecture. I want to publicate some papers in some scientific journals. Next, I want to get some international work experience, maybe in a anglo-saxon country, so I have to learn english. I could do an internship in an architecture office. I also wants to perfect my language skills in french. I want to take part in an international architecture competition to improve my skills in design. After doing all this, I hope to have an important network of contacts that allows me to create my own architecture office.
#
# Grade: 88
# Feature value: 0.008928571428571428
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       In Brazil, is uncommon to find a public school that will have a good performancce, the trend in brasil for to have sucess, it's normal to enter in a particular school, thinking in a good future, in Brasil is not a good place to estudy, the educacion there is not unusual some university studen to came from public school. the trend there are a lof of young and old people studing in the same class, in the private class, as today there are a lot private college, old people trying to get the chance that never had before.
#
# Grade: 90
# Feature value: 0.0
#
#
# ===========================================================================
# Feature code:  LS_FPC_CGA3
# Bin1: 0.0%
# Bin2: 79.7%
# Bin3: 0.0%
# Bin4: 20.3%
#
# 3 sample essays
# Mean: 0.0021, std: 0.0044, Mean-std: -0.0023000000000000004, mean+std: 0.006500000000000001
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       To: xxx@ixwcorporation.com From: xxx@ymail.com Subject: Computer programmer ad.  Dear Mr. Josh Barnes,  I am writting in response to your on line ad for a computer programmer.  I am very interested in the position and I am hardworking and motivated. I work very well with the team. I attached my resume and I have all needed requirements.  I am available for an interview anytime and you can reach me on my cellphone at ####-####.  Thank you very much and I look forward to hearing from you.  Sincerely,  Ftancisco Tupinamba
#
# Grade: 95
# Feature value: 0.008928571428571428
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       First, I have to finish my phd in architecture. I want to publicate some papers in some scientific journals. Next, I want to get some international work experience, maybe in a anglo-saxon country, so I have to learn english. I could do an internship in an architecture office. I also wants to perfect my language skills in french. I want to take part in an international architecture competition to improve my skills in design. After doing all this, I hope to have an important network of contacts that allows me to create my own architecture office.
#
# Grade: 88
# Feature value: 0.0
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  LA_ER
# Bin1: 0.0%
# Bin2: 62.1%
# Bin3: 27.2%
# Bin4: 10.7%
#
# 3 sample essays
# Mean: 0.013, std: 0.0149, Mean-std: -0.0019000000000000006, mean+std: 0.0279
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       First, I have to finish my phd in architecture. I want to publicate some papers in some scientific journals. Next, I want to get some international work experience, maybe in a anglo-saxon country, so I have to learn english. I could do an internship in an architecture office. I also wants to perfect my language skills in french. I want to take part in an international architecture competition to improve my skills in design. After doing all this, I hope to have an important network of contacts that allows me to create my own architecture office.
#
# Grade: 88
# Feature value: 0.017857142857142856
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       In Brazil, is uncommon to find a public school that will have a good performancce, the trend in brasil for to have sucess, it's normal to enter in a particular school, thinking in a good future, in Brasil is not a good place to estudy, the educacion there is not unusual some university studen to came from public school. the trend there are a lof of young and old people studing in the same class, in the private class, as today there are a lot private college, old people trying to get the chance that never had before.
#
# Grade: 90
# Feature value: 0.0625
#
#
# ===========================================================================
# Feature code:  LA_COL_ERR_R
# Bin1: 16.1%
# Bin2: 33.3%
# Bin3: 34.5%
# Bin4: 16.1%
#
# 3 sample essays
# Mean: 0.4594, std: 0.1279, Mean-std: 0.33149999999999996, mean+std: 0.5872999999999999
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       In Brazil, is uncommon to find a public school that will have a good performancce, the trend in brasil for to have sucess, it's normal to enter in a particular school, thinking in a good future, in Brasil is not a good place to estudy, the educacion there is not unusual some university studen to came from public school. the trend there are a lof of young and old people studing in the same class, in the private class, as today there are a lot private college, old people trying to get the chance that never had before.
#
# Grade: 90
# Feature value: 0.21052631578947367
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       First, I have to finish my phd in architecture. I want to publicate some papers in some scientific journals. Next, I want to get some international work experience, maybe in a anglo-saxon country, so I have to learn english. I could do an internship in an architecture office. I also wants to perfect my language skills in french. I want to take part in an international architecture competition to improve my skills in design. After doing all this, I hope to have an important network of contacts that allows me to create my own architecture office.
#
# Grade: 88
# Feature value: 0.36363636363636365
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       To: xxx@ixwcorporation.com From: xxx@ymail.com Subject: Computer programmer ad.  Dear Mr. Josh Barnes,  I am writting in response to your on line ad for a computer programmer.  I am very interested in the position and I am hardworking and motivated. I work very well with the team. I attached my resume and I have all needed requirements.  I am available for an interview anytime and you can reach me on my cellphone at ####-####.  Thank you very much and I look forward to hearing from you.  Sincerely,  Ftancisco Tupinamba
#
# Grade: 95
# Feature value: 0.6956521739130435
#
#
# ===========================================================================
# Feature code:  CA_BIN1_R
# Bin1: 15.8%
# Bin2: 37.4%
# Bin3: 31.0%
# Bin4: 15.8%
#
# 3 sample essays
# Mean: 0.2097, std: 0.1183, Mean-std: 0.0914, mean+std: 0.328
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       In Brazil, is uncommon to find a public school that will have a good performancce, the trend in brasil for to have sucess, it's normal to enter in a particular school, thinking in a good future, in Brasil is not a good place to estudy, the educacion there is not unusual some university studen to came from public school. the trend there are a lof of young and old people studing in the same class, in the private class, as today there are a lot private college, old people trying to get the chance that never had before.
#
# Grade: 90
# Feature value: 0.5535714285714286
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       First, I have to finish my phd in architecture. I want to publicate some papers in some scientific journals. Next, I want to get some international work experience, maybe in a anglo-saxon country, so I have to learn english. I could do an internship in an architecture office. I also wants to perfect my language skills in french. I want to take part in an international architecture competition to improve my skills in design. After doing all this, I hope to have an important network of contacts that allows me to create my own architecture office.
#
# Grade: 88
# Feature value: 0.48214285714285715
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       To: xxx@ixwcorporation.com From: xxx@ymail.com Subject: Computer programmer ad.  Dear Mr. Josh Barnes,  I am writting in response to your on line ad for a computer programmer.  I am very interested in the position and I am hardworking and motivated. I work very well with the team. I attached my resume and I have all needed requirements.  I am available for an interview anytime and you can reach me on my cellphone at ####-####.  Thank you very much and I look forward to hearing from you.  Sincerely,  Ftancisco Tupinamba
#
# Grade: 95
# Feature value: 0.36607142857142855
#
#
# ===========================================================================

# %% [markdown]
# <h1>Level B2 bin percentages</h1>

# %%
level = "b2"
path_to_bins = "bins/bin_values_level_"+level+".xml"
file = open(path_to_bins, "r")
bs = BS(file, "lxml")

binning_criterias = []

features = bs.find_all("feature")

feature_indicies = []
means = []
stdds = []

for index, feature in enumerate(features):
    feature_indicies.append(int(feature.find("feature_index").text))
    means.append(float(feature.find("mean").text))
    stdds.append(float(feature.find("std").text))

feature_indicies = np.array(feature_indicies).round(4)
means = np.array(means).round(4)
stdds = np.array(stdds).round(4)

data = np.vstack((feature_indicies, feature_names[binning_indicies], means, stdds, (means-stdds).round(4), (means+stdds).round(4)))
#print(data)
columns = ["Feature Index", "Feature code", "Mean", "Standard deviation", "mean-std", "mean+std"]

df = pd.DataFrame(data.T, columns=columns)


#read essays
essay_file = "dataset_binned/level_" + level + ".xml"
essays = []
grades = []
index = 0
with open(essay_file, "r") as f:
    bs = BS(f, "lxml")
    writings = bs.find_all("writing")
    for writing in writings:
        #if np.random.normal() < 0.1:
        #    continue
        essays.append(writing.find("text").text)
        grades.append(int(writing.find("grade").text))
        index += 1
        if index == 1000:
            break

bins = []

grades = np.array(grades)
feature_matrix = np.load("all_features_1000/feature_matrix_"+level+"_fm.npy")
grades_test = np.load("all_features_1000/feature_matrix_"+level+"_grades.npy")
assert (grades_test == grades).all()

for index, mean, std in zip(feature_indicies, means, stdds):
    bin1 = len(feature_matrix.T[index, feature_matrix.T[index] <= (mean-std)])
    bin2 = len(feature_matrix.T[index, ((feature_matrix.T[index] <= mean) &  (feature_matrix.T[index] > (mean - std)))])
    bin3 = len(feature_matrix.T[index, ((feature_matrix.T[index] < (mean+std)) &  (feature_matrix.T[index] > mean)) ])
    bin4 = len(feature_matrix.T[index, feature_matrix.T[index] >= (mean+std)]  )
    
    print("Feature code: ", feature_names[index])
    print("Bin1: {}%".format(bin1/10))
    print("Bin2: {}%".format(bin2/10))
    print("Bin3: {}%".format(bin3/10))
    print("Bin4: {}%".format(bin4/10))
    print()
    
    negative_feedback_index = np.argmax((feature_matrix.T[index] <= mean-std)) if ((feature_matrix.T[index] <= mean-std) != False).any() else -1
    neutral_feedback_index = np.argmax((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std))) if ((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std)) != False).any() else -1
    positive_feedback_index = np.argmax((feature_matrix.T[index] >= mean+std)) if ((feature_matrix.T[index] >= mean+std) != False).any() else -1
    
    if feature_names[index] == "LA_ER" or feature_names[index] == "LA_COL_ERR_R" or feature_names[index] == "CA_BIN1_R":
        temp = negative_feedback_index
        negative_feedback_index = positive_feedback_index
        positive_feedback_index = temp
    
    print("3 sample essays")
    print("Mean: {}, std: {}, Mean-std: {}, mean+std: {}".format(mean, std, mean-std, mean+std))
    print("---------------------------------------------------------------------------")
    print("Feedback: Positive")
    print("Essay: {}".format(essays[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Neutral")
    print("Essay: {}".format(essays[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Negative")
    print("Essay: {}".format(essays[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n\n".format(feature_matrix.T[index, negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("===========================================================================")
# Out:
# Feature code:  LV_HDD
# Bin1: 11.6%
# Bin2: 33.8%
# Bin3: 43.1%
# Bin4: 11.5%
#
# 3 sample essays
# Mean: 0.807, std: 0.043, Mean-std: 0.764, mean+std: 0.8500000000000001
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       In my own opinion a successful leader becames with hard work, humility, honesty and dedication, but what is leadership?, I think it's having a most important responsability at any moment, in school, at work or in any kind of team. A good leader teaches, helps, listens, and understand what the problem or situation is about. A good leader never complains, never desistes, take care others. a good leader persuades, motivates, shows the way to resolve. When a leader stop listens its collegue probably it's time to renovate. anyone can be an excellent leader, but actually anybody does not want to, because of our culture, or ourway to think. I diarly encourage my co-workers to do their best every day, I diarly motivate myself.
#
# Grade: 90
# Feature value: 0.8580255261620438
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hi Anna! I've found an absolutely amazing job as Zookeeper for you. Let me tell you why you should apply for this job. You will be responsible for preparing food for the animals and feeding them daily- it sounds totally exciting because you'll get the chance to prove your skills that you're fearless among dangerous animals like lions, crocodiles etc. Likewise, as I can assess, your salary is by far the highest one in comparison to other extreme jobs. You'll get $50.000 and you'll enjoy great benefits like a full accident insurance, one month holiday every year and regular trips to Florida to observe wild crocodiles- it's very exhilarating. I encourage you to apply for this job because I think you have great preconditions to get the job in Flossington Zoo. Warm Greetings Sandra
#
# Grade: 98
# Feature value: 0.8388155641970712
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Hi, I'm a big fan of radical sports, but I like to see only, I don't practice any. In this Month, we can see the Winter Olympic Games and I realize that almost all of type of games are very dangerous and extremely. In Brazil, we don't have a severe winter and because of that we don't have snow and this explain why you don't see a lot of Brazilians in the Winter Olympics. You can trust me when I say to you that I like to see, I wouldn't play most of them. I would play curling, but even this game is dangerous....Although I wouldn't like to play any of these sports, I don't any specific fear, it's just I like to be safer at home.
#
# Grade: 90
# Feature value: 0.7489105120709438
#
#
# ===========================================================================
# Feature code:  LS_FPC_CA
# Bin1: 12.4%
# Bin2: 43.6%
# Bin3: 28.6%
# Bin4: 15.4%
#
# 3 sample essays
# Mean: 0.0301, std: 0.0202, Mean-std: 0.009899999999999999, mean+std: 0.0503
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       From the Performance Appraisal Form that Peter has completed recently, I understand that he has had some difficulties to manage the disagreement with the team, and he also has problems to listen to others. It appears obviously Peter need some management training to help him improve these soft skills. I just read the website information from a training organization, HGMS and found it offers 1, 2, 3 day training packages in a range of &quot;soft skills&quot;. I would like to send Peter on the &quot;Conflict Management&quot; course.  The content includes diffusing tension, settling differences, adapting to workplace norms and listening empathetically. I would suggest a 2 day training length. I am sure through this training course, Peter will enhance his team work and listening skills, as a result better integrate into the team.
#
# Grade: 95
# Feature value: 0.07142857142857142
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hi Anna! I've found an absolutely amazing job as Zookeeper for you. Let me tell you why you should apply for this job. You will be responsible for preparing food for the animals and feeding them daily- it sounds totally exciting because you'll get the chance to prove your skills that you're fearless among dangerous animals like lions, crocodiles etc. Likewise, as I can assess, your salary is by far the highest one in comparison to other extreme jobs. You'll get $50.000 and you'll enjoy great benefits like a full accident insurance, one month holiday every year and regular trips to Florida to observe wild crocodiles- it's very exhilarating. I encourage you to apply for this job because I think you have great preconditions to get the job in Flossington Zoo. Warm Greetings Sandra
#
# Grade: 98
# Feature value: 0
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Media has been in existence for decades in people's lives. When I was growing up, my mother was reading newspaper for learn of all over the world's news. Because there wasn't television in everywhere. We learnt only with our newspapers. But that goes back a ways.Nowadays, media are changed from technological improvements.Readers of newspapers are decreased because of technological tools. These days, there are a lot of tablets or e-books in all of people's lifes. Every knowledge can learnd in everywhere. So people know lots of knowledge about their own lives. I used to books for reading. But now, I am reading e-book with my notebook or tablet. My reading habits is changed. Beacuse more of people's lives are change with new technologies.
#
# Grade: 90
# Feature value: 0.27586206896551724
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hi, Anna! I've found a really great job for you - &quot;Zookeeper at Flossington Zoo&quot;. I urge you to apply for it. Let me tell you about this exhilarating job. The main responsibilities of zookeeper are preparing food for animals and feeding them on a daily basis. You can work with animals, as you really want. It's outside. And such a job can give you enough adrenalin. I have to say, that salary is really attractive - $50 000. Additionally you'll get full accident insurance and 1 month holiday every year. And the most amazing benefit is the regular trips to Florida to observe with crocodiles. I think this job is especially for you. I really want you to apply for it. Please, think about it. Always yours, Samantha
#
# Grade: 90
# Feature value: 0.5789473684210527
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Hi Anna! I've found an absolutely amazing job as Zookeeper for you. Let me tell you why you should apply for this job. You will be responsible for preparing food for the animals and feeding them daily- it sounds totally exciting because you'll get the chance to prove your skills that you're fearless among dangerous animals like lions, crocodiles etc. Likewise, as I can assess, your salary is by far the highest one in comparison to other extreme jobs. You'll get $50.000 and you'll enjoy great benefits like a full accident insurance, one month holiday every year and regular trips to Florida to observe wild crocodiles- it's very exhilarating. I encourage you to apply for this job because I think you have great preconditions to get the job in Flossington Zoo. Warm Greetings Sandra
#
# Grade: 98
# Feature value: 0.6041666666666666
#
#
# ===========================================================================
# Feature code:  CA_BIN1_R
# Bin1: 14.4%
# Bin2: 39.3%
# Bin3: 30.6%
# Bin4: 15.7%
#
# 3 sample essays
# Mean: 0.1867, std: 0.0926, Mean-std: 0.0941, mean+std: 0.2793
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       We always use social networking sites to socialze as well as do business, however we have to be carefully when we use networking sites in respect of security. The major problem is their strength. We could be very loosely connected, this means it is easy to expand unnecessary rumors or our plans to other people. And it is easy to obtain personal data through networking site. There are many networking sites like ProfileMe or Neterwor etc. and each of them have feature for how to use or how to keep information from other people. Although, we have to think about creating specific company policies that limit what our employees share online to keep our company's information in proper way. Social networking site is useful but on the other hand we have to be aware the risk in respect of security.
#
# Grade: 40
# Feature value: 0.030303030303030304
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hi Anna! I've found an absolutely amazing job as Zookeeper for you. Let me tell you why you should apply for this job. You will be responsible for preparing food for the animals and feeding them daily- it sounds totally exciting because you'll get the chance to prove your skills that you're fearless among dangerous animals like lions, crocodiles etc. Likewise, as I can assess, your salary is by far the highest one in comparison to other extreme jobs. You'll get $50.000 and you'll enjoy great benefits like a full accident insurance, one month holiday every year and regular trips to Florida to observe wild crocodiles- it's very exhilarating. I encourage you to apply for this job because I think you have great preconditions to get the job in Flossington Zoo. Warm Greetings Sandra
#
# Grade: 98
# Feature value: 0.21052631578947367
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       From the Performance Appraisal Form that Peter has completed recently, I understand that he has had some difficulties to manage the disagreement with the team, and he also has problems to listen to others. It appears obviously Peter need some management training to help him improve these soft skills. I just read the website information from a training organization, HGMS and found it offers 1, 2, 3 day training packages in a range of &quot;soft skills&quot;. I would like to send Peter on the &quot;Conflict Management&quot; course.  The content includes diffusing tension, settling differences, adapting to workplace norms and listening empathetically. I would suggest a 2 day training length. I am sure through this training course, Peter will enhance his team work and listening skills, as a result better integrate into the team.
#
# Grade: 95
# Feature value: 0.30434782608695654
#
#
# ===========================================================================
# Feature code:  CA_BIN2_R
# Bin1: 14.9%
# Bin2: 40.2%
# Bin3: 28.0%
# Bin4: 16.9%
#
# 3 sample essays
# Mean: 0.1219, std: 0.0756, Mean-std: 0.046299999999999994, mean+std: 0.1975
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       I took up rock climbing when I was just a younger. It was extremely enjoyable, and I gradually became a more-than-competent climber. I continued to practice over the next few years, getting better and better. Once, before I arrived to the summit, I found myself on the land. I had a horrible accident, and broke my leg. It was a terrifying experience; I didn't climbing for a long time after that. However, after I had been away from climbing for a long time, I knew that I would always regret it if I didn't face my fears, so I started climbing again. It was difficult at first, but little by little I felt better and improved. I think I've gotten over most of my fears now.
#
# Grade: 95
# Feature value: 0.21052631578947367
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hi Anna! I've found an absolutely amazing job as Zookeeper for you. Let me tell you why you should apply for this job. You will be responsible for preparing food for the animals and feeding them daily- it sounds totally exciting because you'll get the chance to prove your skills that you're fearless among dangerous animals like lions, crocodiles etc. Likewise, as I can assess, your salary is by far the highest one in comparison to other extreme jobs. You'll get $50.000 and you'll enjoy great benefits like a full accident insurance, one month holiday every year and regular trips to Florida to observe wild crocodiles- it's very exhilarating. I encourage you to apply for this job because I think you have great preconditions to get the job in Flossington Zoo. Warm Greetings Sandra
#
# Grade: 98
# Feature value: 0.15789473684210525
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Hi, I'm a big fan of radical sports, but I like to see only, I don't practice any. In this Month, we can see the Winter Olympic Games and I realize that almost all of type of games are very dangerous and extremely. In Brazil, we don't have a severe winter and because of that we don't have snow and this explain why you don't see a lot of Brazilians in the Winter Olympics. You can trust me when I say to you that I like to see, I wouldn't play most of them. I would play curling, but even this game is dangerous....Although I wouldn't like to play any of these sports, I don't any specific fear, it's just I like to be safer at home.
#
# Grade: 90
# Feature value: 0.043478260869565216
#
#
# ===========================================================================
# Feature code:  CA_BIN3_R
# Bin1: 17.2%
# Bin2: 29.1%
# Bin3: 38.2%
# Bin4: 15.5%
#
# 3 sample essays
# Mean: 0.6914, std: 0.1116, Mean-std: 0.5798, mean+std: 0.803
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       We always use social networking sites to socialze as well as do business, however we have to be carefully when we use networking sites in respect of security. The major problem is their strength. We could be very loosely connected, this means it is easy to expand unnecessary rumors or our plans to other people. And it is easy to obtain personal data through networking site. There are many networking sites like ProfileMe or Neterwor etc. and each of them have feature for how to use or how to keep information from other people. Although, we have to think about creating specific company policies that limit what our employees share online to keep our company's information in proper way. Social networking site is useful but on the other hand we have to be aware the risk in respect of security.
#
# Grade: 40
# Feature value: 0.8787878787878788
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hi Anna! I've found an absolutely amazing job as Zookeeper for you. Let me tell you why you should apply for this job. You will be responsible for preparing food for the animals and feeding them daily- it sounds totally exciting because you'll get the chance to prove your skills that you're fearless among dangerous animals like lions, crocodiles etc. Likewise, as I can assess, your salary is by far the highest one in comparison to other extreme jobs. You'll get $50.000 and you'll enjoy great benefits like a full accident insurance, one month holiday every year and regular trips to Florida to observe wild crocodiles- it's very exhilarating. I encourage you to apply for this job because I think you have great preconditions to get the job in Flossington Zoo. Warm Greetings Sandra
#
# Grade: 98
# Feature value: 0.631578947368421
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       From the Performance Appraisal Form that Peter has completed recently, I understand that he has had some difficulties to manage the disagreement with the team, and he also has problems to listen to others. It appears obviously Peter need some management training to help him improve these soft skills. I just read the website information from a training organization, HGMS and found it offers 1, 2, 3 day training packages in a range of &quot;soft skills&quot;. I would like to send Peter on the &quot;Conflict Management&quot; course.  The content includes diffusing tension, settling differences, adapting to workplace norms and listening empathetically. I would suggest a 2 day training length. I am sure through this training course, Peter will enhance his team work and listening skills, as a result better integrate into the team.
#
# Grade: 95
# Feature value: 0.5652173913043478
#
#
# ===========================================================================
# Feature code:  LD_LXUR
# Bin1: 13.1%
# Bin2: 39.8%
# Bin3: 31.7%
# Bin4: 15.4%
#
# 3 sample essays
# Mean: 0.4848, std: 0.044, Mean-std: 0.4408, mean+std: 0.5288
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       Media has been in existence for decades in people's lives. When I was growing up, my mother was reading newspaper for learn of all over the world's news. Because there wasn't television in everywhere. We learnt only with our newspapers. But that goes back a ways.Nowadays, media are changed from technological improvements.Readers of newspapers are decreased because of technological tools. These days, there are a lot of tablets or e-books in all of people's lifes. Every knowledge can learnd in everywhere. So people know lots of knowledge about their own lives. I used to books for reading. But now, I am reading e-book with my notebook or tablet. My reading habits is changed. Beacuse more of people's lives are change with new technologies.
#
# Grade: 90
# Feature value: 0.5454545454545454
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hi Anna! I've found an absolutely amazing job as Zookeeper for you. Let me tell you why you should apply for this job. You will be responsible for preparing food for the animals and feeding them daily- it sounds totally exciting because you'll get the chance to prove your skills that you're fearless among dangerous animals like lions, crocodiles etc. Likewise, as I can assess, your salary is by far the highest one in comparison to other extreme jobs. You'll get $50.000 and you'll enjoy great benefits like a full accident insurance, one month holiday every year and regular trips to Florida to observe wild crocodiles- it's very exhilarating. I encourage you to apply for this job because I think you have great preconditions to get the job in Flossington Zoo. Warm Greetings Sandra
#
# Grade: 98
# Feature value: 0.44805194805194803
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       Hi, Anna! I've found a really great job for you - &quot;Zookeeper at Flossington Zoo&quot;. I urge you to apply for it. Let me tell you about this exhilarating job. The main responsibilities of zookeeper are preparing food for animals and feeding them on a daily basis. You can work with animals, as you really want. It's outside. And such a job can give you enough adrenalin. I have to say, that salary is really attractive - $50 000. Additionally you'll get full accident insurance and 1 month holiday every year. And the most amazing benefit is the regular trips to Florida to observe with crocodiles. I think this job is especially for you. I really want you to apply for it. Please, think about it. Always yours, Samantha
#
# Grade: 90
# Feature value: 0.4155844155844156
#
#
# ===========================================================================

# %% [markdown]
# <h1>Level C1 bin percentages</h1>

# %%
level = "c1"
path_to_bins = "bins/bin_values_level_"+level+".xml"
file = open(path_to_bins, "r")
bs = BS(file, "lxml")

binning_criterias = []

features = bs.find_all("feature")

feature_indicies = []
means = []
stdds = []

for index, feature in enumerate(features):
    feature_indicies.append(int(feature.find("feature_index").text))
    means.append(float(feature.find("mean").text))
    stdds.append(float(feature.find("std").text))

feature_indicies = np.array(feature_indicies).round(4)
means = np.array(means).round(4)
stdds = np.array(stdds).round(4)

data = np.vstack((feature_indicies, feature_names[binning_indicies], means, stdds, (means-stdds).round(4), (means+stdds).round(4)))
#print(data)
columns = ["Feature Index", "Feature code", "Mean", "Standard deviation", "mean-std", "mean+std"]

df = pd.DataFrame(data.T, columns=columns)


#read essays
essay_file = "dataset_binned/level_" + level + ".xml"
essays = []
grades = []
index = 0
with open(essay_file, "r") as f:
    bs = BS(f, "lxml")
    writings = bs.find_all("writing")
    for writing in writings:
        #if np.random.normal() < 0.1:
        #    continue
        essays.append(writing.find("text").text)
        grades.append(int(writing.find("grade").text))
        index += 1
        if index == 1000:
            break

bins = []

grades = np.array(grades)
feature_matrix = np.load("all_features_1000/feature_matrix_"+level+"_fm.npy")
grades_test = np.load("all_features_1000/feature_matrix_"+level+"_grades.npy")
assert (grades_test == grades).all()

for index, mean, std in zip(feature_indicies, means, stdds):
    bin1 = len(feature_matrix.T[index, feature_matrix.T[index] <= (mean-std)])
    bin2 = len(feature_matrix.T[index, ((feature_matrix.T[index] <= mean) &  (feature_matrix.T[index] > (mean - std)))])
    bin3 = len(feature_matrix.T[index, ((feature_matrix.T[index] < (mean+std)) &  (feature_matrix.T[index] > mean)) ])
    bin4 = len(feature_matrix.T[index, feature_matrix.T[index] >= (mean+std)]  )
    
    print("Feature code: ", feature_names[index])
    print("Bin1: {}%".format(bin1/10))
    print("Bin2: {}%".format(bin2/10))
    print("Bin3: {}%".format(bin3/10))
    print("Bin4: {}%".format(bin4/10))
    print()
    
    negative_feedback_index = np.argmax((feature_matrix.T[index] <= mean-std)) if ((feature_matrix.T[index] <= mean-std) != False).any() else -1
    neutral_feedback_index = np.argmax((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std))) if ((feature_matrix.T[index] > (mean-std)) & (feature_matrix.T[index] < (mean+std)) != False).any() else -1
    positive_feedback_index = np.argmax((feature_matrix.T[index] >= mean+std)) if ((feature_matrix.T[index] >= mean+std) != False).any() else -1
    
    if feature_names[index] == "LA_ER" or feature_names[index] == "LA_COL_ERR_R" or feature_names[index] == "CA_BIN1_R":
        temp = negative_feedback_index
        negative_feedback_index = positive_feedback_index
        positive_feedback_index = temp
    
    print("3 sample essays")
    print("Mean: {}, std: {}, Mean-std: {}, mean+std: {}".format(mean, std, mean-std, mean+std))
    print("---------------------------------------------------------------------------")
    print("Feedback: Positive")
    print("Essay: {}".format(essays[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, positive_feedback_index] if positive_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Neutral")
    print("Essay: {}".format(essays[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n".format(feature_matrix.T[index, neutral_feedback_index] if neutral_feedback_index != -1 else "No sample"))
    print("---------------------------------------------------------------------------")
    print("Feedback: Negative")
    print("Essay: {}".format(essays[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Grade: {}".format(grades[negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("Feature value: {}\n\n".format(feature_matrix.T[index, negative_feedback_index] if negative_feedback_index != -1 else "No sample"))
    print("===========================================================================")
# Out:
# Feature code:  LV_HDD
# Bin1: 15.3%
# Bin2: 32.4%
# Bin3: 37.5%
# Bin4: 14.8%
#
# 3 sample essays
# Mean: 0.8182, std: 0.0333, Mean-std: 0.7849, mean+std: 0.8515
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       I think that every company should build a CSR program. It's not only my opinion, because in Italy even our constitutional law, at his article 41, says that &quot;...the economic activity, both public and private, will be addressed and coordinated towards social purposes&quot;. Other than the law, many companies build projects that underline their giving back to the society. Surely, this will guarantee them some news coverage, but these actions will provide good outcomes. For instance, many companies are sponsoring small sport teams, even in minor sports that otherwise wouldn't have the money to make their activities. Or, other companies devolve some hours of their workers to help the community to maintain public goods like parks, games, schools and so on. These can all be ways to underline the link between an industry and its society, and ultimately can also stimulate their workers to work better, feeling that they are not only working for their salary, but also for a bigger purpose.
#
# Grade: 95
# Feature value: 0.8870580773332439
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hello everybody,Some of you might know me! I am the father of the bride and really, really proud of my lovely daughter today. I want to say a few words about her wedding. But first of all I want to thank all of you to be with us here today!To begin with Id like to let you know how I met my son-in-low the first time. When I met Doug, I didnt know they were dating and Jessica hadnt told him I didnt know. But direct from the beginning I knew that there is a special link between them I am proud and glad to welcome Doug to our family!I have a special toast for the couple! I want to quote my father: My greatest wish for you both is that through the years your love for each other will grow so much, that years from now you will look back on this day, your wedding day, as the day you loved each other the least.
#
# Grade: 94
# Feature value: 0.8099804570089976
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       As a mayor council I have maintained the deep scrutiny of a hydropower dam building problem in the river which surround my city. The bill from an energy supply company is the main &quot;consumer&quot; in the average famylies budget so reducing it is the goal of our mayor who is searching for a public endorsement. Although there is a few major points which make the idea of the buliding considerable. Of course first of all is the cost of a construction relatively to sunlight panels. It is cheaper in the price of panels, instalation of the panels and maintanance. Furthermore there is still need for large sums of the batery for accumulating and suppling a sun power. And the second reason is in the core of wind plants. The last ones is deathly noisy for the insects and mammals in the area of the such plants.Despite we have a planty of offers from both German and local builders, we need to overcome the last handicap - a monopoly of our non-enviromentally frendly suppliers.
#
# Grade: 70
# Feature value: 0.7606551811084067
#
#
# ===========================================================================
# Feature code:  LS_FPC_CA
# Bin1: 18.8%
# Bin2: 38.5%
# Bin3: 28.5%
# Bin4: 14.2%
#
# 3 sample essays
# Mean: 0.0327, std: 0.0209, Mean-std: 0.011800000000000001, mean+std: 0.053599999999999995
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       I think that every company should build a CSR program. It's not only my opinion, because in Italy even our constitutional law, at his article 41, says that &quot;...the economic activity, both public and private, will be addressed and coordinated towards social purposes&quot;. Other than the law, many companies build projects that underline their giving back to the society. Surely, this will guarantee them some news coverage, but these actions will provide good outcomes. For instance, many companies are sponsoring small sport teams, even in minor sports that otherwise wouldn't have the money to make their activities. Or, other companies devolve some hours of their workers to help the community to maintain public goods like parks, games, schools and so on. These can all be ways to underline the link between an industry and its society, and ultimately can also stimulate their workers to work better, feeling that they are not only working for their salary, but also for a bigger purpose.
#
# Grade: 95
# Feature value: 0.06282722513089005
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       Hello everybody,Some of you might know me! I am the father of the bride and really, really proud of my lovely daughter today. I want to say a few words about her wedding. But first of all I want to thank all of you to be with us here today!To begin with Id like to let you know how I met my son-in-low the first time. When I met Doug, I didnt know they were dating and Jessica hadnt told him I didnt know. But direct from the beginning I knew that there is a special link between them I am proud and glad to welcome Doug to our family!I have a special toast for the couple! I want to quote my father: My greatest wish for you both is that through the years your love for each other will grow so much, that years from now you will look back on this day, your wedding day, as the day you loved each other the least.
#
# Grade: 94
# Feature value: 0.015706806282722512
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       I think that every company should build a CSR program. It's not only my opinion, because in Italy even our constitutional law, at his article 41, says that &quot;...the economic activity, both public and private, will be addressed and coordinated towards social purposes&quot;. Other than the law, many companies build projects that underline their giving back to the society. Surely, this will guarantee them some news coverage, but these actions will provide good outcomes. For instance, many companies are sponsoring small sport teams, even in minor sports that otherwise wouldn't have the money to make their activities. Or, other companies devolve some hours of their workers to help the community to maintain public goods like parks, games, schools and so on. These can all be ways to underline the link between an industry and its society, and ultimately can also stimulate their workers to work better, feeling that they are not only working for their salary, but also for a bigger purpose.
#
# Grade: 95
# Feature value: 0.0
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
#
# ===========================================================================
# Feature code:  LA_ER
# Bin1: 0.0%
# Bin2: 68.0%
# Bin3: 19.9%
# Bin4: 12.1%
#
# 3 sample essays
# Mean: 0.011, std: 0.0114, Mean-std: -0.00040000000000000105, mean+std: 0.0224
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay: No sample
# Grade: No sample
# Feature value: No sample
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       I think that every company should build a CSR program. It's not only my opinion, because in Italy even our constitutional law, at his article 41, says that &quot;...the economic activity, both public and private, will be addressed and coordinated towards social purposes&quot;. Other than the law, many companies build projects that underline their giving back to the society. Surely, this will guarantee them some news coverage, but these actions will provide good outcomes. For instance, many companies are sponsoring small sport teams, even in minor sports that otherwise wouldn't have the money to make their activities. Or, other companies devolve some hours of their workers to help the community to maintain public goods like parks, games, schools and so on. These can all be ways to underline the link between an industry and its society, and ultimately can also stimulate their workers to work better, feeling that they are not only working for their salary, but also for a bigger purpose.
#
# Grade: 95
# Feature value: 0.0
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       As a mayor council I have maintained the deep scrutiny of a hydropower dam building problem in the river which surround my city. The bill from an energy supply company is the main &quot;consumer&quot; in the average famylies budget so reducing it is the goal of our mayor who is searching for a public endorsement. Although there is a few major points which make the idea of the buliding considerable. Of course first of all is the cost of a construction relatively to sunlight panels. It is cheaper in the price of panels, instalation of the panels and maintanance. Furthermore there is still need for large sums of the batery for accumulating and suppling a sun power. And the second reason is in the core of wind plants. The last ones is deathly noisy for the insects and mammals in the area of the such plants.Despite we have a planty of offers from both German and local builders, we need to overcome the last handicap - a monopoly of our non-enviromentally frendly suppliers.
#
# Grade: 70
# Feature value: 0.05235602094240838
#
#
# ===========================================================================
# Feature code:  LA_COL_ERR_R
# Bin1: 16.5%
# Bin2: 36.0%
# Bin3: 29.7%
# Bin4: 17.8%
#
# 3 sample essays
# Mean: 0.4764, std: 0.1221, Mean-std: 0.3543, mean+std: 0.5985
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#       It is not easy to pinpoint what traits make people successful. When I think of a successful person, one of my former students comes to my mind. He was an absolutely hard-working guy, but his hard work did not prevent him from failure. My student was very resilient. He was always able to bounce back from adversity. No matter what happened, he never gave up. He was very persistent. He had been an excellent student and later on he was able to turn his academic success into business success. He is incredibly passionate about his work as an entrepreneur today. He has the great ability to find pragmatic solutions to problems. He understands what people want. Obviously, he does not lack empathy. Empathy, in a way that he is able to put himself in other people's shoes. He not only understands what people want, but also how they feel. I have nothing but respect for him and I am completely proud of my former student.
#
# Grade: 100
# Feature value: 0.34545454545454546
#
# ---------------------------------------------------------------------------
# Feedback: Neutral
# Essay:
#       I think that every company should build a CSR program. It's not only my opinion, because in Italy even our constitutional law, at his article 41, says that &quot;...the economic activity, both public and private, will be addressed and coordinated towards social purposes&quot;. Other than the law, many companies build projects that underline their giving back to the society. Surely, this will guarantee them some news coverage, but these actions will provide good outcomes. For instance, many companies are sponsoring small sport teams, even in minor sports that otherwise wouldn't have the money to make their activities. Or, other companies devolve some hours of their workers to help the community to maintain public goods like parks, games, schools and so on. These can all be ways to underline the link between an industry and its society, and ultimately can also stimulate their workers to work better, feeling that they are not only working for their salary, but also for a bigger purpose.
#
# Grade: 95
# Feature value: 0.4666666666666667
#
# ---------------------------------------------------------------------------
# Feedback: Negative
# Essay:
#       How about more peace and quiet in your life? You can get some now when you rent this amazing apartment on Pacific Heights. The size will suit even a family of four, with three spacious bedrooms and two modern bathrooms. The kitchen has just been thoroughly remodeled, so you can enjoy a clean and modern cooking space. There is a long breakfast bar with granite countertops, for your family to enjoy meals together. The rest of the house has maintained its traditional looks, with a very well-preserved original wood staircase, which is the first thing anyone will notice as they enter your home. If you appreciate open spaces and fresh air, you'll simply love the beautiful rustic porch. There, you'll be able to appreciate the most breathtaking views of the neighbourhood. The rent is extremely affordable considering all the advantages of this amazing apartment, in such an excellent location. The apartment rents for $1,850 monthly, a small price to pay for such comfort and luxury.
#
# Grade: 98
# Feature value: 0.7183098591549296
#
#
# ===========================================================================
# Feature code:  CA_BIN1_R
# Bin1: 15.1%
# Bin2: 40.7%
# Bin3: 27.5%
# Bin4: 16.7%
#
# 3 sample essays
# Mean: 0.1913, std: 0.0836, Mean-std: 0.1077, mean+std: 0.2749
# ---------------------------------------------------------------------------
# Feedback: Positive
# Essay:
#