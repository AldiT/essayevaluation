# %%
import numpy as np
import pandas as pd
from scipy.stats import pearsonr

# %%
level = "a1"
ld_features = np.load("level_" + level + "_fm_ld.npy")
feature_matrix = np.load("feature_matrices/level_" + level + "_fm.npy")
grades = np.load("feature_matrices/level_" + level + "_grades.npy")
simon_features = np.load("simon_features/" + level + ".npy")


ld_features = ld_features[:1000, :]
feature_matrix = feature_matrix[:1000, :]
grades = grades[:1000]


print("Ld features: ", ld_features.shape)
print("LVLS features: ", feature_matrix.shape)
print("Grades: ", grades.shape)
print("Simon features: ", simon_features.shape)
feature_matrix = np.concatenate((feature_matrix, simon_features, ld_features), axis=1)
print("Feature matrix shape: ", feature_matrix.shape)
# Out:
# Ld features:  (1000, 2)
# LVLS features:  (1000, 28)
# Grades:  (1000,)
# Simon features:  (1000, 9)
# Feature matrix shape:  (1000, 39)

# %%
#14 features
features_lv = ['LV_W', 'LV_WT', 'LV_WT1', 'LV_TTR', 'LV_CTTR', 'LV_RTTR', 'LV_HDD', 'LV_DUGA', 'LV_MAAS', 'LV_SUMM',
                         'LV_YULEK','LV_MTLD','LV_MSTTR','LV_MATTR']

#14 features
features_ls = ["LS_FPC_NG", "LS_FPC_NA", "LS_FPC_TC", "LS_FPC_BS", "LS_FPC_CA", "LS_FPC_CT", "LS_FPC_CGA1",
            "LS_FPC_CGA2", "LS_FPC_CGA3", "LS_FOMN_NG", "LS_FOMN_NA", "LS_FOMN_TC", "LS_FOMN_BS", "LS_FOMN_CA"]
#3 features
features_la = ["LA_E", "LA_ER", "LA_COL_ERR_R"]
#6 features
features_ca = ["CA_BIN1_R", "CA_BIN2_R", "CA_BIN3_R", "CA_BIN1", "CA_BIN2", "CA_BIN3"]
#2 features
features_ld = ["LD_LXUR", "LD_GRUR"]

feature_names = features_lv + features_ls + features_la + features_ca + features_ld

feature_names
# Out:
# ['LV_W',
#  'LV_WT',
#  'LV_WT1',
#  'LV_TTR',
#  'LV_CTTR',
#  'LV_RTTR',
#  'LV_HDD',
#  'LV_DUGA',
#  'LV_MAAS',
#  'LV_SUMM',
#  'LV_YULEK',
#  'LV_MTLD',
#  'LV_MSTTR',
#  'LV_MATTR',
#  'LS_FPC_NG',
#  'LS_FPC_NA',
#  'LS_FPC_TC',
#  'LS_FPC_BS',
#  'LS_FPC_CA',
#  'LS_FPC_CT',
#  'LS_FPC_CGA1',
#  'LS_FPC_CGA2',
#  'LS_FPC_CGA3',
#  'LS_FOMN_NG',
#  'LS_FOMN_NA',
#  'LS_FOMN_TC',
#  'LS_FOMN_BS',
#  'LS_FOMN_CA',
#  'LA_E',
#  'LA_ER',
#  'LA_COL',
#  'CA_BIN1_R',
#  'CA_BIN2_R',
#  'CA_BIN3_R',
#  'CA_BIN1',
#  'CA_BIN2',
#  'CA_BIN3',
#  'LD_LXUR',
#  'LD_GRUR']

# %% [markdown]
# <h1>Level A1</h1>

# %% [markdown]
# <h3>Lexical Variation table</h3>

# %%
pearson_correlation_lv = []
p_scores_lv = []

for column in feature_matrix[:, :14].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_lv.append(calcs[0])
    p_scores_lv.append(calcs[1])

pearson_correlation_lv = np.array(pearson_correlation_lv)

data = np.stack([feature_names[:14], pearson_correlation_lv, p_scores_lv])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#      Feature    Pearson_Correlation                p_score
# 8    LV_MAAS   0.050075278435018744    0.11352824678640386
# 10  LV_YULEK    0.03915958927671976    0.21599030838267655
# 12  LV_MSTTR   0.032932522542861144     0.2981552693758958
# 13  LV_MATTR   0.031708350937864886    0.31648663600257554
# 1      LV_WT   -0.14142790293451674   7.14467543206572e-06
# 0       LV_W   -0.13529853501836575  1.763402093410244e-05
# 6     LV_HDD   -0.10761847273709794  0.0006523902931818127
# 2     LV_WT1    -0.1066775669043027  0.0007278507553030212
# 5    LV_RTTR   -0.10064508656571959   0.001438605900892104
# 4    LV_CTTR   -0.10064508656571956   0.001438605900892104
# 9    LV_SUMM   -0.04810161243648108     0.1284898619059701
# 11   LV_MTLD   -0.04011597881392169     0.2049757676161695
# 7    LV_DUGA   -0.03710284399114609     0.2411042816477608
# 3     LV_TTR  -0.034400377735838414    0.27712673457193554

# %% [markdown]
# <h3>Lexical Sophistication table</h3>

# %%
pearson_correlation_ls = []
p_scores_ls = []

for column in feature_matrix[:, 14:28].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ls.append(calcs[0])
    p_scores_ls.append(calcs[1])

pearson_correlation_ls = np.array(pearson_correlation_ls)

data = np.stack([feature_names[14:28], pearson_correlation_ls, p_scores_ls])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#         Feature    Pearson_Correlation                p_score
# 2     LS_FPC_TC    0.10542666630279142  0.0008407350385196706
# 11   LS_FOMN_TC    0.04286189586432373    0.17562814346569708
# 9    LS_FOMN_NG    0.03688868505030479     0.2438327102725922
# 12   LS_FOMN_BS   0.031215298903707084     0.3240741683235767
# 7   LS_FPC_CGA2   0.029913132937975536     0.3446769084060146
# 6   LS_FPC_CGA1   -0.10414935906254785   0.000972561230719049
# 10   LS_FOMN_NA    -0.0814673448554104   0.009957937766326228
# 13   LS_FOMN_CA   -0.06429757441369988    0.04206985093089647
# 8   LS_FPC_CGA3   -0.06322886301838632    0.04561139974315776
# 1     LS_FPC_NA   -0.03365700634318199     0.2876468019356835
# 5     LS_FPC_CT   -0.01801498720343742     0.5693442119930094
# 0     LS_FPC_NG  -0.014895508079598947     0.6380161989494993
# 3     LS_FPC_BS  -0.009117216499891117     0.7733795866308828
# 4     LS_FPC_CA   -0.00806881658350591     0.7988440524783618

# %% [markdown]
# <h3>Lexical Accuracy table</h3>

# %%
pearson_correlation_la = []
p_scores_la = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 28:31].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_la.append(calcs[0])
    p_scores_la.append(calcs[1])

pearson_correlation_la = np.array(pearson_correlation_la)

data = np.stack([feature_names[28:31], pearson_correlation_la, p_scores_la])

df = pd.DataFrame(data.T, index=np.arange(3), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#   Feature   Pearson_Correlation                p_score
# 1   LA_ER  -0.20344615429504448  8.385739359530021e-11
# 0    LA_E  -0.20344002592901128  8.396873072787383e-11
# 2  LA_COL    -0.072746553007191    0.02141314784475967

# %% [markdown]
# <h3>Collocational Aspects table</h3>

# %%
pearson_correlation_ca = []
p_scores_ca = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 31:37].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ca.append(calcs[0])
    p_scores_ca.append(calcs[1])

pearson_correlation_ca = np.array(pearson_correlation_ca)

data = np.stack([feature_names[31:37], pearson_correlation_ca, p_scores_ca])

df = pd.DataFrame(data.T, index=np.arange(6), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#      Feature   Pearson_Correlation                p_score
# 5    CA_BIN3   0.09219602007991508  0.0035221136345164232
# 3    CA_BIN1   0.03436261933810486    0.27765469162776907
# 4    CA_BIN2   0.03080452476746278    0.33048512324563806
# 0  CA_BIN1_R  0.019908692603691342     0.5294518134194831
# 1  CA_BIN2_R   0.00906502132867369     0.7746418529375005
# 2  CA_BIN3_R  -0.02482213349930813    0.43299091433145376

# %% [markdown]
# <h3>Lexical Density table</h3>

# %%
pearson_correlation_ld = []
p_scores_ld = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 37:39].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ld.append(calcs[0])
    p_scores_ld.append(calcs[1])

pearson_correlation_ld = np.array(pearson_correlation_ld)

data = np.stack([feature_names[37:39], pearson_correlation_ld, p_scores_ld])

df = pd.DataFrame(data.T, index=np.arange(2), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#    Feature    Pearson_Correlation              p_score
# 0  LD_LXUR  -0.043189163949450854  0.17235053886805446
# 1  LD_GRUR  -0.007462075074172771   0.8136812387903698

# %% [markdown]
# <h1>Level A2</h1>

# %%
level = "a2"
ld_features = np.load("level_" + level + "_fm_ld.npy")
feature_matrix = np.load("feature_matrices/level_" + level + "_fm.npy")
grades = np.load("feature_matrices/level_" + level + "_grades.npy")
simon_features = np.load("simon_features/" + level + ".npy")

ld_features = ld_features[:1000, :]
feature_matrix = feature_matrix[:1000, :]
grades = grades[:1000]

print("Ld features: ", ld_features.shape)
print("LVLS features: ", feature_matrix.shape)
print("Grades: ", grades.shape)
print("Simon features: ", simon_features.shape)
feature_matrix = np.concatenate((feature_matrix, simon_features, ld_features), axis=1)
print("Feature matrix shape: ", feature_matrix.shape)
# Out:
# Ld features:  (1000, 2)
# LVLS features:  (1000, 28)
# Grades:  (1000,)
# Simon features:  (1000, 9)
# Feature matrix shape:  (1000, 39)

# %% [markdown]
# <h3>Lexical Variation table</h3>

# %%
pearson_correlation_lv = []
p_scores_lv = []

for column in feature_matrix[:, :14].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_lv.append(calcs[0])
    p_scores_lv.append(calcs[1])

pearson_correlation_lv = np.array(pearson_correlation_lv)

data = np.stack([feature_names[:14], pearson_correlation_lv, p_scores_lv])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#      Feature    Pearson_Correlation               p_score
# 10  LV_YULEK     0.0666893426789358  0.034978061920487385
# 8    LV_MAAS    0.06030965575728316   0.05658419230382163
# 13  LV_MATTR   -0.09772400132453114  0.001975793485565102
# 0       LV_W   -0.08630423455016203  0.006316877029853407
# 1      LV_WT   -0.07972351567502389  0.011670934277667706
# 4    LV_CTTR   -0.06606343065766619   0.03672767815087777
# 5    LV_RTTR   -0.06606343065766614   0.03672767815087777
# 2     LV_WT1   -0.06459812090209929   0.04111678320698014
# 6     LV_HDD   -0.06055168876069188   0.05559789564151638
# 9    LV_SUMM   -0.05974950532244361    0.0589226916788868
# 12  LV_MSTTR   -0.05950649427802957   0.05996183770467719
# 3     LV_TTR  -0.048180954224023395   0.12786024965102763
# 11   LV_MTLD   -0.04143656753124312   0.19044535366096538
# 7    LV_DUGA  -0.030564632170310104    0.3342667761730023

# %% [markdown]
# <h3>Lexical Sophistication table</h3>

# %%
pearson_correlation_ls = []
p_scores_ls = []

for column in feature_matrix[:, 14:28].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ls.append(calcs[0])
    p_scores_ls.append(calcs[1])

pearson_correlation_ls = np.array(pearson_correlation_ls)

data = np.stack([feature_names[14:28], pearson_correlation_ls, p_scores_ls])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#         Feature     Pearson_Correlation              p_score
# 2     LS_FPC_TC     0.06946024730645817  0.02806104445746701
# 7   LS_FPC_CGA2      0.0573407744995099  0.06990927998643232
# 8   LS_FPC_CGA3     0.04174804311329575  0.18713134924461736
# 13   LS_FOMN_CA    0.024922274928738018  0.43113664360942944
# 5     LS_FPC_CT      0.0238232616544672   0.4517370594459501
# 10   LS_FOMN_NA    0.002945329255440766   0.9258851306367982
# 6   LS_FPC_CGA1    -0.06716505445326434  0.03369628525118199
# 0     LS_FPC_NG    -0.06033025549544268  0.05649968506287793
# 1     LS_FPC_NA   -0.020366231481683872   0.5200307538068951
# 9    LS_FOMN_NG   -0.018391362455847254    0.561302678494541
# 12   LS_FOMN_BS    -0.00832999766018329   0.7924790857337202
# 11   LS_FOMN_TC   -0.007378790888159933   0.8157232105271596
# 4     LS_FPC_CA   -0.006899198417942902   0.8275058336291236
# 3     LS_FPC_BS  -0.0006334094189215943   0.9840392926485958

# %% [markdown]
# <h3>Lexical Accuracy table</h3>

# %%
pearson_correlation_la = []
p_scores_la = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 28:31].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_la.append(calcs[0])
    p_scores_la.append(calcs[1])

pearson_correlation_la = np.array(pearson_correlation_la)

data = np.stack([feature_names[28:31], pearson_correlation_la, p_scores_la])

df = pd.DataFrame(data.T, index=np.arange(3), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#   Feature   Pearson_Correlation                 p_score
# 0    LA_E    -0.178330758218169   1.364128058457104e-08
# 1   LA_ER  -0.17830789513900813  1.3700387182960392e-08
# 2  LA_COL  -0.04268657873771661     0.17740293693782663

# %% [markdown]
# <h3>Collocational Aspects table</h3>

# %%
pearson_correlation_ca = []
p_scores_ca = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 31:37].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ca.append(calcs[0])
    p_scores_ca.append(calcs[1])

pearson_correlation_ca = np.array(pearson_correlation_ca)

data = np.stack([feature_names[31:37], pearson_correlation_ca, p_scores_ca])

df = pd.DataFrame(data.T, index=np.arange(6), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#      Feature    Pearson_Correlation               p_score
# 2  CA_BIN3_R    0.06285188848375443   0.04691905466002523
# 5    CA_BIN3    0.03802161109143035   0.22964280474476606
# 0  CA_BIN1_R    -0.0628481162328574  0.046932297406753545
# 3    CA_BIN1   -0.05012604444356757   0.11316230564051014
# 1  CA_BIN2_R  -0.013774520882213852    0.6635156558504283
# 4    CA_BIN2  -0.009932742311770467    0.7537369164577216

# %% [markdown]
# <h3>Lexical Density table</h3>

# %%
pearson_correlation_ld = []
p_scores_ld = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 37:39].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ld.append(calcs[0])
    p_scores_ld.append(calcs[1])

pearson_correlation_ld = np.array(pearson_correlation_ld)

data = np.stack([feature_names[37:39], pearson_correlation_ld, p_scores_ld])

df = pd.DataFrame(data.T, index=np.arange(2), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#    Feature   Pearson_Correlation                p_score
# 1  LD_GRUR   0.05188750371960315    0.10103023407513036
# 0  LD_LXUR  -0.12277020266075778  9.933455898464886e-05

# %% [markdown]
# <h1>Level B1</h1>

# %%
level = "b1"
ld_features = np.load("level_" + level + "_fm_ld.npy")
feature_matrix = np.load("feature_matrices/level_" + level + "_fm.npy")
grades = np.load("feature_matrices/level_" + level + "_grades.npy")
simon_features = np.load("simon_features/" + level + ".npy")

ld_features = ld_features[:1000, :]
feature_matrix = feature_matrix[:1000, :]
grades = grades[:1000]

print("Ld features: ", ld_features.shape)
print("LVLS features: ", feature_matrix.shape)
print("Grades: ", grades.shape)
print("Simon features: ", simon_features.shape)
feature_matrix = np.concatenate((feature_matrix, simon_features, ld_features), axis=1)
print("Feature matrix shape: ", feature_matrix.shape)
# Out:
# Ld features:  (1000, 2)
# LVLS features:  (1000, 28)
# Grades:  (1000,)
# Simon features:  (1000, 9)
# Feature matrix shape:  (1000, 39)

# %% [markdown]
# <h3>Lexical Variation table</h3>

# %%
pearson_correlation_lv = []
p_scores_lv = []

for column in feature_matrix[:, :14].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_lv.append(calcs[0])
    p_scores_lv.append(calcs[1])

pearson_correlation_lv = np.array(pearson_correlation_lv)

data = np.stack([feature_names[:14], pearson_correlation_lv, p_scores_lv])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#      Feature   Pearson_Correlation              p_score
# 7    LV_DUGA  0.054749640703891725  0.08354664635395506
# 3     LV_TTR   0.05427639420600541  0.08625575523305973
# 9    LV_SUMM   0.04913433992609109  0.12048076128014028
# 6     LV_HDD  0.041144771799640524   0.1935889312673607
# 11   LV_MTLD  0.037748952139646394  0.23300304488660759
# 4    LV_CTTR   0.03439696542004266   0.2771744192099763
# 5    LV_RTTR   0.03439696542004266   0.2771744192099763
# 2     LV_WT1  0.033285445323059444  0.29300463532787996
# 12  LV_MSTTR  0.027128747028700287   0.3914608816761824
# 1      LV_WT   0.01303323027451009   0.6805967603329319
# 13  LV_MATTR  0.004123889378673444   0.8963715790790652
# 0       LV_W  -0.06655833533118533  0.03533826922207952
# 8    LV_MAAS  -0.04853656980265119  0.12506767178136452
# 10  LV_YULEK  -0.03732387579395819  0.23831087605144843

# %% [markdown]
# <h3>Lexical Sophistication table</h3>

# %%
pearson_correlation_ls = []
p_scores_ls = []

for column in feature_matrix[:, 14:28].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ls.append(calcs[0])
    p_scores_ls.append(calcs[1])

pearson_correlation_ls = np.array(pearson_correlation_ls)

data = np.stack([feature_names[14:28], pearson_correlation_ls, p_scores_ls])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#         Feature    Pearson_Correlation               p_score
# 3     LS_FPC_BS    0.06050159935391597  0.055800830332933815
# 5     LS_FPC_CT   0.050542347320288276   0.11019633599985804
# 0     LS_FPC_NG    0.04650555400059207   0.14167267933601932
# 8   LS_FPC_CGA3    0.04583052521787008   0.14755083047016196
# 4     LS_FPC_CA    0.04549190749401721    0.1505687542236983
# 7   LS_FPC_CGA2   0.043520444360155494    0.1690795001417438
# 13   LS_FOMN_CA   0.039645930965957143   0.21033716422873935
# 2     LS_FPC_TC     0.0388322308588647    0.2198564689588065
# 6   LS_FPC_CGA1   0.022857481026295322   0.47028998761268875
# 12   LS_FOMN_BS  0.0014500761529967082     0.963471168395005
# 1     LS_FPC_NA  -0.026280843851729883    0.4064386026055141
# 10   LS_FOMN_NA  -0.017038873615104907    0.5904516445930198
# 9    LS_FOMN_NG   -0.01035387190307542    0.7436546982411222
# 11   LS_FOMN_TC  -0.004462888708281655    0.8879069758671099

# %% [markdown]
# <h3>Lexcial Accuracy table</h3>

# %%
pearson_correlation_la = []
p_scores_la = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 28:31].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_la.append(calcs[0])
    p_scores_la.append(calcs[1])

pearson_correlation_la = np.array(pearson_correlation_la)

data = np.stack([feature_names[28:31], pearson_correlation_la, p_scores_la])

df = pd.DataFrame(data.T, index=np.arange(3), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#   Feature    Pearson_Correlation                p_score
# 1   LA_ER   -0.17363733431248796  3.275107059724742e-08
# 0    LA_E   -0.17354776259850638  3.329548882927822e-08
# 2  LA_COL  -0.014662538318771038      0.643281833180628

# %% [markdown]
# <h3>Collocational Aspects table</h3>

# %%
pearson_correlation_ca = []
p_scores_ca = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 31:37].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ca.append(calcs[0])
    p_scores_ca.append(calcs[1])

pearson_correlation_ca = np.array(pearson_correlation_ca)

data = np.stack([feature_names[31:37], pearson_correlation_ca, p_scores_ca])

df = pd.DataFrame(data.T, index=np.arange(6), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#      Feature     Pearson_Correlation              p_score
# 5    CA_BIN3    0.022629811272362067  0.47472400383693514
# 3    CA_BIN1    0.021580156060823252   0.4954600935583788
# 0  CA_BIN1_R    0.004846888108237694   0.8783341951065988
# 1  CA_BIN2_R  -0.0062334654920759925   0.8439254688981797
# 4    CA_BIN2   -0.002122666315681597   0.9465492829051965
# 2  CA_BIN3_R  -0.0002027624870215811   0.9948904672572871

# %% [markdown]
# <h3>Lexical Density table</h3>

# %%
pearson_correlation_ld = []
p_scores_ld = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 37:39].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ld.append(calcs[0])
    p_scores_ld.append(calcs[1])

pearson_correlation_ld = np.array(pearson_correlation_ld)

data = np.stack([feature_names[37:39], pearson_correlation_ld, p_scores_ld])

df = pd.DataFrame(data.T, index=np.arange(2), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#    Feature   Pearson_Correlation             p_score
# 0  LD_LXUR  0.007359949452881017  0.8161853410146879
# 1  LD_GRUR  0.007251427670128319  0.8188483307503909

# %% [markdown]
# <h1>Level B2</h1>

# %%
level = "b2"
ld_features = np.load("level_" + level + "_fm_ld.npy")
feature_matrix = np.load("feature_matrices/level_" + level + "_fm.npy")
grades = np.load("feature_matrices/level_" + level + "_grades.npy")
simon_features = np.load("simon_features/" + level + ".npy")


ld_features = ld_features[:1000, :]
feature_matrix = feature_matrix[:1000, :]
grades = grades[:1000]


print("Ld features: ", ld_features.shape)
print("LVLS features: ", feature_matrix.shape)
print("Grades: ", grades.shape)
print("Simon features: ", simon_features.shape)
feature_matrix = np.concatenate((feature_matrix, simon_features, ld_features), axis=1)
print("Feature matrix shape: ", feature_matrix.shape)
# Out:
# Ld features:  (1000, 2)
# LVLS features:  (1000, 28)
# Grades:  (1000,)
# Simon features:  (1000, 9)
# Feature matrix shape:  (1000, 39)

# %% [markdown]
# <h3>Lexical Variation table</h3>

# %%
pearson_correlation_lv = []
p_scores_lv = []

for column in feature_matrix[:, :14].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_lv.append(calcs[0])
    p_scores_lv.append(calcs[1])

pearson_correlation_lv = np.array(pearson_correlation_lv)

data = np.stack([feature_names[:14], pearson_correlation_lv, p_scores_lv])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#      Feature    Pearson_Correlation              p_score
# 11   LV_MTLD   0.029494300713135413   0.3514771919437323
# 7    LV_DUGA   0.021023557990851816   0.5066486054109152
# 6     LV_HDD    0.02070144119028913   0.5131837380022898
# 3     LV_TTR    0.01728358021656177   0.5851264393449243
# 9    LV_SUMM   0.016134271645071682    0.610327864679831
# 4    LV_CTTR   0.014005273227287984   0.6582334978602019
# 5    LV_RTTR   0.014005273227287984   0.6582334978602019
# 2     LV_WT1   0.011303226665272443   0.7210889911924865
# 1      LV_WT   0.010371152345507569   0.7432419114549643
# 13  LV_MATTR   0.006138949915025023   0.8462622757335131
# 10  LV_YULEK   -0.03152973319448268  0.31922181280403517
# 8    LV_MAAS   -0.01604011309618444   0.6124136831300279
# 0       LV_W   -0.00847763242012183   0.7888873053706917
# 12  LV_MSTTR  -0.002827180517388802   0.9288501236137263

# %% [markdown]
# <h3>Lexical Sophistication table</h3>

# %%
pearson_correlation_ls = []
p_scores_ls = []

for column in feature_matrix[:, 14:28].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ls.append(calcs[0])
    p_scores_ls.append(calcs[1])

pearson_correlation_ls = np.array(pearson_correlation_ls)

data = np.stack([feature_names[14:28], pearson_correlation_ls, p_scores_ls])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#         Feature    Pearson_Correlation              p_score
# 5     LS_FPC_CT    0.05828003765050673  0.06544040767535594
# 1     LS_FPC_NA    0.05517272961899467  0.08118330673087405
# 2     LS_FPC_TC    0.05455764415991422  0.08463732220753818
# 3     LS_FPC_BS    0.05368200520468606  0.08975824435806086
# 0     LS_FPC_NG    0.04140293375781539  0.19080577190571385
# 7   LS_FPC_CGA2    0.02527880657994027   0.4245723613474184
# 6   LS_FPC_CGA1   0.017691423373621794    0.576300991436622
# 10   LS_FOMN_NA   0.012593614735025915   0.6908050808107653
# 12   LS_FOMN_BS   0.009734292981527167   0.7585026614209049
# 4     LS_FPC_CA    0.00797421589632249   0.8011527861846368
# 11   LS_FOMN_TC   0.003736195197354063   0.9060664639618244
# 8   LS_FPC_CGA3  -0.021315734073137308   0.5007589145577204
# 13   LS_FOMN_CA  -0.019589129234217587   0.5360828750392829
# 9    LS_FOMN_NG  -0.009453865637449689   0.7652527121004007

# %% [markdown]
# <h3>Lexical Accuracy table</h3>

# %%
pearson_correlation_la = []
p_scores_la = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 28:31].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_la.append(calcs[0])
    p_scores_la.append(calcs[1])

pearson_correlation_la = np.array(pearson_correlation_la)

data = np.stack([feature_names[28:31], pearson_correlation_la, p_scores_la])

df = pd.DataFrame(data.T, index=np.arange(3), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#   Feature   Pearson_Correlation                 p_score
# 2  LA_COL  0.009142880147910834      0.7727591668156288
# 1   LA_ER  -0.20058450131229752  1.5511219969124907e-10
# 0    LA_E  -0.20015516893768343   1.699730333612322e-10

# %% [markdown]
# <h3>Collocational Aspects table</h3>

# %%
pearson_correlation_ca = []
p_scores_ca = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 31:37].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ca.append(calcs[0])
    p_scores_ca.append(calcs[1])

pearson_correlation_ca = np.array(pearson_correlation_ca)

data = np.stack([feature_names[31:37], pearson_correlation_ca, p_scores_ca])

df = pd.DataFrame(data.T, index=np.arange(6), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#      Feature    Pearson_Correlation              p_score
# 3    CA_BIN1   0.026900316526206492      0.3954626860661
# 2  CA_BIN3_R   0.022317446587784024   0.4808446241265061
# 5    CA_BIN3   0.020982480537770982   0.5074795511576164
# 0  CA_BIN1_R   0.015489201639104952   0.6246800801892527
# 1  CA_BIN2_R  -0.051872921239677516  0.10112624417318485
# 4    CA_BIN2   -0.04640305354383023  0.14255350182663992

# %% [markdown]
# <h3>Lexical Density table</h3>

# %%
pearson_correlation_ld = []
p_scores_ld = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 37:39].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ld.append(calcs[0])
    p_scores_ld.append(calcs[1])

pearson_correlation_ld = np.array(pearson_correlation_ld)

data = np.stack([feature_names[37:39], pearson_correlation_ld, p_scores_ld])

df = pd.DataFrame(data.T, index=np.arange(2), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#    Feature     Pearson_Correlation              p_score
# 1  LD_GRUR    0.050427173093003375  0.11101069663778515
# 0  LD_LXUR  -0.0044963557718686615   0.8870719998154283

# %% [markdown]
# <h1>Level C1</h1>

# %%
level = "c1"
ld_features = np.load("level_" + level + "_fm_ld.npy")
feature_matrix = np.load("feature_matrices/level_" + level + "_fm.npy")
grades = np.load("feature_matrices/level_" + level + "_grades.npy")
simon_features = np.load("simon_features/" + level + ".npy")


ld_features = ld_features[:1000, :]
feature_matrix = feature_matrix[:1000, :]
grades = grades[:1000]


print("Ld features: ", ld_features.shape)
print("LVLS features: ", feature_matrix.shape)
print("Grades: ", grades.shape)
print("Simon features: ", simon_features.shape)
feature_matrix = np.concatenate((feature_matrix, simon_features, ld_features), axis=1)
print("Feature matrix shape: ", feature_matrix.shape)
# Out:
# Ld features:  (1000, 2)
# LVLS features:  (1000, 28)
# Grades:  (1000,)
# Simon features:  (1000, 9)
# Feature matrix shape:  (1000, 39)

# %% [markdown]
# <h3>Lexical Variation table</h3>

# %%
pearson_correlation_lv = []
p_scores_lv = []

for column in feature_matrix[:, :14].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_lv.append(calcs[0])
    p_scores_lv.append(calcs[1])

pearson_correlation_lv = np.array(pearson_correlation_lv)

data = np.stack([feature_names[:14], pearson_correlation_lv, p_scores_lv])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#      Feature    Pearson_Correlation               p_score
# 2     LV_WT1    0.07830665754622045  0.013249891236953242
# 1      LV_WT    0.07613845143305552   0.01603165079811942
# 9    LV_SUMM     0.0740159293227171  0.019238698894134598
# 4    LV_CTTR    0.07334550264626044  0.020361857943218598
# 5    LV_RTTR    0.07334550264626043  0.020361857943218598
# 3     LV_TTR    0.06608952521271659   0.03665327615414799
# 6     LV_HDD    0.05716946396411308   0.07075072085403859
# 7    LV_DUGA    0.05456383045477252   0.08460200123626092
# 13  LV_MATTR   0.049314303300486625   0.11912589922295559
# 12  LV_MSTTR    0.03990313916976429    0.2073910109813644
# 11   LV_MTLD   0.029073457030585975    0.3583950001362699
# 0       LV_W    0.02116221863396936    0.5038489561639947
# 8    LV_MAAS   -0.07379113820502514  0.019609111726957968
# 10  LV_YULEK  -0.051301046963970316   0.10494898843395979

# %% [markdown]
# <h3>Lexical Sophistication table</h3>

# %%
pearson_correlation_ls = []
p_scores_ls = []

for column in feature_matrix[:, 14:28].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ls.append(calcs[0])
    p_scores_ls.append(calcs[1])

pearson_correlation_ls = np.array(pearson_correlation_ls)

data = np.stack([feature_names[14:28], pearson_correlation_ls, p_scores_ls])

df = pd.DataFrame(data.T, index=np.arange(14), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
#         Feature     Pearson_Correlation                 p_score
# 6   LS_FPC_CGA1     0.13255777344259376  2.6088365564050813e-05
# 2     LS_FPC_TC     0.09489531105419112    0.002665595731961662
# 0     LS_FPC_NG     0.08648611598198395    0.006207026366453751
# 3     LS_FPC_BS     0.06288182420826581     0.04681407449587196
# 8   LS_FPC_CGA3    0.057948373567070145      0.0669907730227049
# 7   LS_FPC_CGA2     0.04662113298300718       0.140684483235848
# 13   LS_FOMN_CA     0.03447961601791587     0.27602100646097955
# 12   LS_FOMN_BS    0.030814468599903503      0.3303289683091587
# 5     LS_FPC_CT    0.020498167606560303      0.5173302154697185
# 4     LS_FPC_CA    0.008863638451131077      0.7795175614098447
# 11   LS_FOMN_TC    -0.10219478536154009   0.0012116777336864692
# 10   LS_FOMN_NA    -0.05834468484132744     0.06514168093775696
# 1     LS_FPC_NA   -0.043179749379618056     0.17244418352225027
# 9    LS_FOMN_NG  -0.0036637004456106553      0.9078809023386594

# %% [markdown]
# <h3>Lexical Accuracy table</h3>

# %%
pearson_correlation_la = []
p_scores_la = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 28:31].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_la.append(calcs[0])
    p_scores_la.append(calcs[1])

pearson_correlation_la = np.array(pearson_correlation_la)

data = np.stack([feature_names[28:31], pearson_correlation_la, p_scores_la])

df = pd.DataFrame(data.T, index=np.arange(3), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#   Feature   Pearson_Correlation                p_score
# 2  LA_COL   0.03897797866153178    0.21812908121735639
# 1   LA_ER  -0.19301772026247618  7.551386998384898e-10
# 0    LA_E  -0.19252510913930598  8.352770684998635e-10

# %% [markdown]
# <h3>Collocational Aspects table</h3>

# %%
pearson_correlation_ca = []
p_scores_ca = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 31:37].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ca.append(calcs[0])
    p_scores_ca.append(calcs[1])

pearson_correlation_ca = np.array(pearson_correlation_ca)

data = np.stack([feature_names[31:37], pearson_correlation_ca, p_scores_ca])

df = pd.DataFrame(data.T, index=np.arange(6), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#      Feature    Pearson_Correlation               p_score
# 2  CA_BIN3_R    0.06573221899446029   0.03768326141545039
# 5    CA_BIN3   0.040176090769513034    0.2042973469934094
# 0  CA_BIN1_R  -0.059797089582055755  0.058720973197801736
# 3    CA_BIN1   -0.04996533629098352   0.11432394254723834
# 1  CA_BIN2_R   -0.02495476097682479    0.4305361042741382
# 4    CA_BIN2   -0.01053432634225898    0.7393477386482922

# %% [markdown]
# <h3>Lexical Density table</h3>

# %%
pearson_correlation_ld = []
p_scores_ld = []
print("Feature matrix shape: ", feature_matrix.shape)
for column in feature_matrix[:, 37:39].T:
    calcs = pearsonr(column, grades)
    pearson_correlation_ld.append(calcs[0])
    p_scores_ld.append(calcs[1])

pearson_correlation_ld = np.array(pearson_correlation_ld)

data = np.stack([feature_names[37:39], pearson_correlation_ld, p_scores_ld])

df = pd.DataFrame(data.T, index=np.arange(2), columns=["Feature", "Pearson_Correlation", "p_score"])
df.sort_values(by="Pearson_Correlation", ascending=False)
# Out:
# Feature matrix shape:  (1000, 39)
#    Feature    Pearson_Correlation              p_score
# 0  LD_LXUR  4.676266948772163e-05    0.998821592009806
# 1  LD_GRUR   0.048653029730886345  0.12416352863588505
